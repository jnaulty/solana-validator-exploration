# %% [markdown]
# # Solana Validator Exploration
#
# Initial Questions:
#
# * How many validators have the Identity and Vote Account as the same pubkey?
# * How many validators have open RPC (and potentially unauthenticated RPC ports?
# * How many validators have different network addresses for gossip, tpu, and rpc?

# %%
import requests
import pandas as pd

# %%
# https://docs.solana.com/cluster/rpc-endpoints#mainnet-beta
SOLANA_RPC_URL = "https://api.mainnet-beta.solana.com"

headers = {"Content-Type": "application/json"}
data = {"jsonrpc":"2.0", "id": 1}

# %%
def solana_rpc_call(headers, data):
    r = requests.post(SOLANA_RPC_URL, headers=headers, json=data)
    response_data = r.json()
    print(response_data)
    return response_data 


def getClusterNodes(data):
    """
docs: https://docs.solana.com/developing/clients/jsonrpc-api#getclusternodes

input: none

output:
pubkey: <string> - Node public key, as base-58 encoded string
gossip: <string | null> - Gossip network address for the node
tpu: <string | null> - TPU network address for the node
rpc: <string | null> - JSON RPC network address for the node, or null if the JSON RPC service is not enabled
version: <string | null> - The software version of the node, or null if the version information is not available
featureSet: <u32 | null > - The unique identifier of the node's feature set
shredVersion: <u16 | null> - The shred version the node has been configured to use


curl http://localhost:8899 -X POST -H "Content-Type: application/json" -d '
  {"jsonrpc":"2.0", "id":1, "method":"getClusterNodes"}
'
    """
    
    data["method"] = "getClusterNodes"
    return solana_rpc_call(headers, data)

# %%
def getVoteAccounts(data):
    """
docs: https://docs.solana.com/developing/clients/jsonrpc-api#getvoteaccounts

parameters:
<object> - (optional) Configuration object containing the following field:
(optional) Commitment
(optional) votePubkey: <string> - Only return results for this validator vote address (base-58 encoded)
(optional) keepUnstakedDelinquents: <bool> - Do not filter out delinquent validators with no stake
(optional) delinquentSlotDistance: <u64> - Specify the number of slots behind the tip that a validator must fall to be considered delinquent. NOTE: For the sake of consistency between ecosystem products, it is not recommended that this argument be specified.

output:
votePubkey: <string> - Vote account address, as base-58 encoded string
nodePubkey: <string> - Validator identity, as base-58 encoded string
activatedStake: <u64> - the stake, in lamports, delegated to this vote account and active in this epoch
epochVoteAccount: <bool> - bool, whether the vote account is staked for this epoch
commission: <number>, percentage (0-100) of rewards payout owed to the vote account
lastVote: <u64> - Most recent slot voted on by this vote account
epochCredits: <array> - History of how many credits earned by the end of each epoch, as an array of arrays containing: [epoch, credits, previousCredits]

    """

    data["method"] = "getVoteAccounts"
    return solana_rpc_call(headers, data)

# %%
clusterNodeResponse = getClusterNodes(data)
# Out:
# {'jsonrpc': '2.0', 'result': [{'featureSet': 483097211, 'gossip': '93.187.216.181:8001', 'pubkey': 'CrTdNk65pAcBzf5krCVHW1KTKSxPAdyQPWe2gcKgiqDz', 'rpc': None, 'shredVersion': 51382, 'tpu': '93.187.216.181:8004', 'version': '1.10.35'}, {'featureSet': 2324890699, 'gossip': '141.95.35.64:8001', 'pubkey': 'C219S526JWRzpPUm3FfAzobwZMDuo3DM63phtJpqAz75', 'rpc': None, 'shredVersion': 51382, 'tpu': '141.95.35.64:8004', 'version': '1.10.38'}, {'featureSet': 2324890699, 'gossip': '142.132.128.140:8001', 'pubkey': 'E1SFkvPjU31xWMcvgnX6vhGvfRvb1zXvHFkqmQNEGZKK', 'rpc': None, 'shredVersion': 51382, 'tpu': '142.132.128.140:8003', 'version': '1.10.38'}, {'featureSet': 2324890699, 'gossip': '65.108.70.123:8001', 'pubkey': '2FMWJN52AeqnoTECeicyk724fJbMZLXVyMopBWThyZ1U', 'rpc': None, 'shredVersion': 51382, 'tpu': '65.108.70.123:8004', 'version': '1.10.38'}, {'featureSet': 2324890699, 'gossip': '104.243.41.140:8000', 'pubkey': '84Za5eXvehQLZR6Xqhe9WT6tTcCHTVjw3XU7GCbBRNfW', 'rpc': '104.243.41.140:8899', 'shredVersion': 51382, 'tpu': '104.243.41.140:8003', 'version': '1.10.38'}, {'featureSet': 483097211, 'gossip': '168.119.138.160:8000', 'pubkey': 'EwUVzgSPe1zy2hfUGZxJAEP7Y1wheNgNsgratbzPELru', 'rpc': None, 'shredVersion': 51382, 'tpu': '168.119.138.160:8003', 'version': '1.10.35'}, {'featureSet': 2324890699, 'gossip': '65.21.92.216:8001', 'pubkey': '73A8PnqdHraWe9W5jiYzUBPEf4giyTxUG1CKZ6HkXbuz', 'rpc': None, 'shredVersion': 51382, 'tpu': '65.21.92.216:8004', 'version': '1.10.38'}, {'featureSet': 483097211, 'gossip': '65.108.47.146:8000', 'pubkey': 'BSNJGveGPVYzdt2bhTh3YfqbzWPH5Sq38zT1Br88Pn1N', 'rpc': None, 'shredVersion': 51382, 'tpu': '65.108.47.146:8003', 'version': '1.10.34'}, {'featureSet': 2324890699, 'gossip': '85.10.192.170:8000', 'pubkey': 'FG5w8e7nBXivh4N5zwMDyFrj5sMx11NUnd5wCmNfPZ6b', 'rpc': '85.10.192.170:8899', 'shredVersion': 51382, 'tpu': '85.10.192.170:8003', 'version': '1.10.38'}, {'featureSet': 483097211, 'gossip': '142.132.252.100:8000', 'pubkey': 'J2obR2DK7gnd6H88HjKzEYuMyboDWRNpbzwmGSh31nnu', 'rpc': None, 'shredVersion': 51382, 'tpu': '142.132.252.100:8003', 'version': '1.10.34'}, {'featureSet': 2324890699, 'gossip': '92.253.237.52:8001', 'pubkey': 'GRmtMtAeSL8HgX1p815ATQjaYU4Sk7XCP21i4yoFd3KS', 'rpc': None, 'shredVersion': 51382, 'tpu': '92.253.237.52:8004', 'version': '1.10.38'}, {'featureSet': 2324890699, 'gossip': '195.201.203.12:8000', 'pubkey': '3nRhescC7HMYC8gKti3ENiBe8LnKZUs2gzYPAjYniQCP', 'rpc': None, 'shredVersion': 51382, 'tpu': '195.201.203.12:8003', 'version': '1.10.38'}, {'featureSet': 2324890699, 'gossip': '173.231.59.162:8001', 'pubkey': 'E5j5YwUZmKZwTMJeJnwyhhmBaRDT3qHyFgPuqSPmN743', 'rpc': None, 'shredVersion': 51382, 'tpu': '173.231.59.162:8004', 'version': '1.10.38'}, {'featureSet': 483097211, 'gossip': '147.75.42.163:8001', 'pubkey': '38mTPbpSCC3iPrdM5KKy2kXAjdSdw6GyNndMKvgHDoNv', 'rpc': None, 'shredVersion': 51382, 'tpu': '147.75.42.163:8003', 'version': '1.10.35'}, {'featureSet': 2324890699, 'gossip': '185.155.17.90:8000', 'pubkey': '4vvaKfJyXfvyvk3Uq8CGMTWTs7ATw9mLgK4XbpVMe1vo', 'rpc': None, 'shredVersion': 51382, 'tpu': '185.155.17.90:8003', 'version': '1.10.38'}, {'featureSet': 2324890699, 'gossip': '216.18.218.146:8001', 'pubkey': 'FSq3EXWdLvUDBVgZ47joponPRq12NRUfXoCwZbeL9Eh', 'rpc': None, 'shredVersion': 51382, 'tpu': '216.18.218.146:8004', 'version': '1.10.38'}, {'featureSet': 2324890699, 'gossip': '145.40.113.193:8000', 'pubkey': 'CAo1dCGYrB6NhHh5xb1cGjUiu86iyCfMTENxgHumSve4', 'rpc': None, 'shredVersion': 51382, 'tpu': '145.40.113.193:8003', 'version': '1.10.38'}, {'featureSet': 2324890699, 'gossip': '142.132.128.132:8000', 'pubkey': 'DE37cgN2bGR26a1yQPPY42CozC1wXwXnTXDyyURHRsm7', 'rpc': '142.132.128.132:8899', 'shredVersion': 51382, 'tpu': '142.132.128.132:8003', 'version': '1.10.38'}, {'featureSet': 483097211, 'gossip': '92.63.195.91:8021', 'pubkey': '8ne4sDgaaMtuwY1y4BaMYSGKXpDRVc1Po9PsJQvrZPMs', 'rpc': None, 'shredVersion': 51382, 'tpu': '92.63.195.91:8024', 'version': '1.10.35'}, {'feature ...

# %%
voteAccountsResponse = getVoteAccounts(data)
# Out:
# {'jsonrpc': '2.0', 'result': {'current': [{'activatedStake': 73446440809731, 'commission': 10, 'epochCredits': [[340, 43315131, 42947787], [341, 43668868, 43315131], [342, 44054134, 43668868], [343, 44419787, 44054134], [344, 44422166, 44419787]], 'epochVoteAccount': True, 'lastVote': 148610907, 'nodePubkey': 'EJQfuuRgKngEE199LYyqAdNqmE3Ms5EMwLa7F7a4PuWA', 'rootSlot': 148610867, 'votePubkey': '59ygup4yDt6s7BEtACkbrUQnutK6883ThPx6ZS7QrFb4'}, {'activatedStake': 71439993594343, 'commission': 10, 'epochCredits': [[340, 9389689, 9021867], [341, 9743124, 9389689], [342, 10128186, 9743124], [343, 10496903, 10128186], [344, 10499278, 10496903]], 'epochVoteAccount': True, 'lastVote': 148610906, 'nodePubkey': 'CFeXt8sBqgagHSkbsPfw9MpbffmxwBVKp6Jdjc8yACeQ', 'rootSlot': 148610866, 'votePubkey': 'C33g1CBgcc47XFcrYksA3CEkBKaitKuhs9yD7LLtW98K'}, {'activatedStake': 202162131716288, 'commission': 100, 'epochCredits': [[340, 42961309, 42593818], [341, 43314851, 42961309], [342, 43700489, 43314851], [343, 44072395, 43700489], [344, 44074739, 44072395]], 'epochVoteAccount': True, 'lastVote': 148610895, 'nodePubkey': '8L3JhKEZWiCyvVuEAzXeDjkziptj1XZsFFZReD5s3DZY', 'rootSlot': 148610863, 'votePubkey': '3JwUXwdCHLazV1oaUY8Yg87eWS8sE7qTpbJ2BZRQBjru'}, {'activatedStake': 72763333999262, 'commission': 10, 'epochCredits': [[340, 28322393, 27955157], [341, 28652627, 28322393], [342, 29037788, 28652627], [343, 29409600, 29037788], [344, 29411998, 29409600]], 'epochVoteAccount': True, 'lastVote': 148610907, 'nodePubkey': '3mPiMjCvfawQD753b3jw4YPWwywTg6bBrRwmj5gmXWcD', 'rootSlot': 148610866, 'votePubkey': '4ebYDbb3D9mjgAYc813oJ8aQtSE3u6QRu3rBHxiJ72Pk'}, {'activatedStake': 2591235614994379, 'commission': 100, 'epochCredits': [[340, 61509702, 61142220], [341, 61860579, 61509702], [342, 62245441, 61860579], [343, 62615744, 62245441], [344, 62618106, 62615744]], 'epochVoteAccount': True, 'lastVote': 148610906, 'nodePubkey': 'EaRH6eMWnXKXhw1tqve6eUXnsoWYUFKeSbXUyBEqyPYJ', 'rootSlot': 148610866, 'votePubkey': '31J7VodSmMhebVNmR3BVsBkv4rrpbEmGKQm1yKscsZH5'}, {'activatedStake': 72998934236367, 'commission': 10, 'epochCredits': [[340, 17030751, 16663001], [341, 17358521, 17030751], [342, 17744155, 17358521], [343, 18114886, 17744155], [344, 18117246, 18114886]], 'epochVoteAccount': True, 'lastVote': 148610905, 'nodePubkey': '69ZPqJi4jMt3CirCwtXuYt7D9wrCyVo898GJdDVS3G8k', 'rootSlot': 148610866, 'votePubkey': 'GrtCNjHDd9dFwJ2HVCR26rKBfvDXHav6wkDZT8F5d4E2'}, {'activatedStake': 80295114057202, 'commission': 10, 'epochCredits': [[340, 45629965, 45262128], [341, 45943572, 45629965], [342, 46328587, 45943572], [343, 46699781, 46328587], [344, 46702137, 46699781]], 'epochVoteAccount': True, 'lastVote': 148610905, 'nodePubkey': '3Urw79qk7EoFoxwPurb8j3RiSK21pcP1mSVe1q7HGXbk', 'rootSlot': 148610866, 'votePubkey': 'BrF3uiDCn4yX55kZ5wcGN6NBUdg9pksWRzaniBALJLJu'}, {'activatedStake': 84325396860932, 'commission': 10, 'epochCredits': [[340, 11594267, 11240290], [341, 11947875, 11594267], [342, 12332974, 11947875], [343, 12692812, 12332974], [344, 12695183, 12692812]], 'epochVoteAccount': True, 'lastVote': 148610905, 'nodePubkey': 'FPPo2aGYYwDWK1Rmr4sXjiCaZzzMwGKi67ijAiVZKwb8', 'rootSlot': 148610865, 'votePubkey': 'FKCcfoLt2pq7boiNqRGucVq5LE1K5Dt4HALCx2WbEQkv'}, {'activatedStake': 85342172977977, 'commission': 10, 'epochCredits': [[340, 45652851, 45284932], [341, 46006922, 45652851], [342, 46392394, 46006922], [343, 46762681, 46392394], [344, 46765070, 46762681]], 'epochVoteAccount': True, 'lastVote': 148610905, 'nodePubkey': '7U3WxfMKFzoEetvJUAyea139aGnv2kkrTS8s6SovXuix', 'rootSlot': 148610863, 'votePubkey': 'EdWcTxPcysbL6Y4rpJXdCYAP2RmL9Eyor1hKp6uyCD2S'}, {'activatedStake': 70810072807707, 'commission': 10, 'epochCredits': [[340, 4833354, 4468140], [341, 5185747, 4833354], [342, 5570611, 5185747], [343, 5940368, 5570611], [344, 5942765, 5940368]], 'epochVoteAccount': True, 'lastVote': 148610907, 'nodePubkey': 'DDMM7C218XeNSDqw8us9szA1Ss92Ag7EJE9rGEz8Qtdo', 'rootSlot': 148610867, ' ...

# %%
def parseResponse(response):
    """
    
    """
    result = response.get('result', None)
    return result

# %%
voteAccountsResults = parseResponse(voteAccountsResponse)
voteAccountsResults['current']
# Out:
# [{'activatedStake': 73446440809731,
#   'commission': 10,
#   'epochCredits': [[340, 43315131, 42947787],
#    [341, 43668868, 43315131],
#    [342, 44054134, 43668868],
#    [343, 44419787, 44054134],
#    [344, 44422166, 44419787]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'EJQfuuRgKngEE199LYyqAdNqmE3Ms5EMwLa7F7a4PuWA',
#   'rootSlot': 148610867,
#   'votePubkey': '59ygup4yDt6s7BEtACkbrUQnutK6883ThPx6ZS7QrFb4'},
#  {'activatedStake': 71439993594343,
#   'commission': 10,
#   'epochCredits': [[340, 9389689, 9021867],
#    [341, 9743124, 9389689],
#    [342, 10128186, 9743124],
#    [343, 10496903, 10128186],
#    [344, 10499278, 10496903]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': 'CFeXt8sBqgagHSkbsPfw9MpbffmxwBVKp6Jdjc8yACeQ',
#   'rootSlot': 148610866,
#   'votePubkey': 'C33g1CBgcc47XFcrYksA3CEkBKaitKuhs9yD7LLtW98K'},
#  {'activatedStake': 202162131716288,
#   'commission': 100,
#   'epochCredits': [[340, 42961309, 42593818],
#    [341, 43314851, 42961309],
#    [342, 43700489, 43314851],
#    [343, 44072395, 43700489],
#    [344, 44074739, 44072395]],
#   'epochVoteAccount': True,
#   'lastVote': 148610895,
#   'nodePubkey': '8L3JhKEZWiCyvVuEAzXeDjkziptj1XZsFFZReD5s3DZY',
#   'rootSlot': 148610863,
#   'votePubkey': '3JwUXwdCHLazV1oaUY8Yg87eWS8sE7qTpbJ2BZRQBjru'},
#  {'activatedStake': 72763333999262,
#   'commission': 10,
#   'epochCredits': [[340, 28322393, 27955157],
#    [341, 28652627, 28322393],
#    [342, 29037788, 28652627],
#    [343, 29409600, 29037788],
#    [344, 29411998, 29409600]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '3mPiMjCvfawQD753b3jw4YPWwywTg6bBrRwmj5gmXWcD',
#   'rootSlot': 148610866,
#   'votePubkey': '4ebYDbb3D9mjgAYc813oJ8aQtSE3u6QRu3rBHxiJ72Pk'},
#  {'activatedStake': 2591235614994379,
#   'commission': 100,
#   'epochCredits': [[340, 61509702, 61142220],
#    [341, 61860579, 61509702],
#    [342, 62245441, 61860579],
#    [343, 62615744, 62245441],
#    [344, 62618106, 62615744]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': 'EaRH6eMWnXKXhw1tqve6eUXnsoWYUFKeSbXUyBEqyPYJ',
#   'rootSlot': 148610866,
#   'votePubkey': '31J7VodSmMhebVNmR3BVsBkv4rrpbEmGKQm1yKscsZH5'},
#  {'activatedStake': 72998934236367,
#   'commission': 10,
#   'epochCredits': [[340, 17030751, 16663001],
#    [341, 17358521, 17030751],
#    [342, 17744155, 17358521],
#    [343, 18114886, 17744155],
#    [344, 18117246, 18114886]],
#   'epochVoteAccount': True,
#   'lastVote': 148610905,
#   'nodePubkey': '69ZPqJi4jMt3CirCwtXuYt7D9wrCyVo898GJdDVS3G8k',
#   'rootSlot': 148610866,
#   'votePubkey': 'GrtCNjHDd9dFwJ2HVCR26rKBfvDXHav6wkDZT8F5d4E2'},
#  {'activatedStake': 80295114057202,
#   'commission': 10,
#   'epochCredits': [[340, 45629965, 45262128],
#    [341, 45943572, 45629965],
#    [342, 46328587, 45943572],
#    [343, 46699781, 46328587],
#    [344, 46702137, 46699781]],
#   'epochVoteAccount': True,
#   'lastVote': 148610905,
#   'nodePubkey': '3Urw79qk7EoFoxwPurb8j3RiSK21pcP1mSVe1q7HGXbk',
#   'rootSlot': 148610866,
#   'votePubkey': 'BrF3uiDCn4yX55kZ5wcGN6NBUdg9pksWRzaniBALJLJu'},
#  {'activatedStake': 84325396860932,
#   'commission': 10,
#   'epochCredits': [[340, 11594267, 11240290],
#    [341, 11947875, 11594267],
#    [342, 12332974, 11947875],
#    [343, 12692812, 12332974],
#    [344, 12695183, 12692812]],
#   'epochVoteAccount': True,
#   'lastVote': 148610905,
#   'nodePubkey': 'FPPo2aGYYwDWK1Rmr4sXjiCaZzzMwGKi67ijAiVZKwb8',
#   'rootSlot': 148610865,
#   'votePubkey': 'FKCcfoLt2pq7boiNqRGucVq5LE1K5Dt4HALCx2WbEQkv'},
#  {'activatedStake': 85342172977977,
#   'commission': 10,
#   'epochCredits': [[340, 45652851, 45284932],
#    [341, 46006922, 45652851],
#    [342, 46392394, 46006922],
#    [343, 46762681, 46392394],
#    [344, 46765070, 46762681]],
#   'epochVoteAccount': True,
#   'lastVote': 148610905,
#   'nodePubkey': '7U3WxfMKFzoEetvJUAyea139aGnv2kkrTS8s6SovXuix',
#   'rootSlot': 148610863,
#   'votePubkey': 'EdWcTxPcysbL6Y4rpJXdCYAP2RmL9Eyor1hKp6uyCD2S'},
#  {'activatedStake': 70810072807707,
#   'commission': 10,
#   'epochCredits': [[340, 4833354, 4468140],
#    [341, 5185747, 4833354],
#    [342, 5570611, 5185747],
#    [343, 5940368, 5570611],
#    [344, 5942765, 5940368]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'DDMM7C218XeNSDqw8us9szA1Ss92Ag7EJE9rGEz8Qtdo',
#   'rootSlot': 148610867,
#   'votePubkey': '52HBJgFBWwMSk6maAqMshgc1iniQKrRiTgXsQCCT66XA'},
#  {'activatedStake': 73599768938602,
#   'commission': 10,
#   'epochCredits': [[340, 47225060, 46857299],
#    [341, 47579039, 47225060],
#    [342, 47963925, 47579039],
#    [343, 48327318, 47963925],
#    [344, 48329694, 48327318]],
#   'epochVoteAccount': True,
#   'lastVote': 148610895,
#   'nodePubkey': '9wPR3SBeG3USxccsCXYC79xZtpNg1FoEnAwV6N6XvLf8',
#   'rootSlot': 148610863,
#   'votePubkey': 'H9r1MBpJEwixFwaVgryJpwUHJShE24pBw2SBfSWyf2HN'},
#  {'activatedStake': 72378372355944,
#   'commission': 10,
#   'epochCredits': [[340, 21950119, 21594960],
#    [341, 22303139, 21950119],
#    [342, 22687885, 22303139],
#    [343, 23058440, 22687885],
#    [344, 23060808, 23058440]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '77fHHpiSzS9vaPfi4DxEBgCQWGjsoH9dWTFb5aud4RMg',
#   'rootSlot': 148610863,
#   'votePubkey': '7K316SSJjaLvm95CQe2XuLjYsntQqUDUAwQ71jZZdRxw'},
#  {'activatedStake': 72068304799176,
#   'commission': 10,
#   'epochCredits': [[340, 10615096, 10250891],
#    [341, 10964195, 10615096],
#    [342, 11346954, 10964195],
#    [343, 11714500, 11346954],
#    [344, 11716846, 11714500]],
#   'epochVoteAccount': True,
#   'lastVote': 148610895,
#   'nodePubkey': 'Cq3GbqG7Hw7m9gsj6gip2XfrJQwn7YhGo1kUAnZqZiAe',
#   'rootSlot': 148610863,
#   'votePubkey': 'DxANoZyiDiNo6v8z2BSwMspKpvPY3on3afSt8uGMuFKH'},
#  {'activatedStake': 74032784580460,
#   'commission': 10,
#   'epochCredits': [[340, 62417518, 62052185],
#    [341, 62771363, 62417518],
#    [342, 63156367, 62771363],
#    [343, 63524702, 63156367],
#    [344, 63527091, 63524702]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'DFKj3e6WeQmLxQkRBHq7nqcEXjwkcfJGCt22VySeDiKx',
#   'rootSlot': 148610867,
#   'votePubkey': 'o8Fcigd8DDix22S39yiS1aegYdTWUo5dBaeBasyK6F4'},
#  {'activatedStake': 72901044625881,
#   'commission': 10,
#   'epochCredits': [[340, 28419202, 28054922],
#    [341, 28768312, 28419202],
#    [342, 29150826, 28768312],
#    [343, 29519531, 29150826],
#    [344, 29521889, 29519531]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'B3uXszjkQfWAhs5eBSPvoapddJGuBN32ncNFi7CMjmYD',
#   'rootSlot': 148610863,
#   'votePubkey': 'EtGWDbP7342Mo2PnG6MYUP1rL8v69ycn1FRnRTB1BLU3'},
#  {'activatedStake': 465265164139816,
#   'commission': 100,
#   'epochCredits': [[340, 17013287, 16645261],
#    [341, 17358583, 17013287],
#    [342, 17743813, 17358583],
#    [343, 18115384, 17743813],
#    [344, 18117747, 18115384]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'Fxsn579uS4xAWHWNR9v4A3m2upUnACYcDuhKmL2fbRmu',
#   'rootSlot': 148610863,
#   'votePubkey': '7ZTtXhSM2zEUrgRkS9jUPmSshyuBDdLVvWbk9hW7sLYS'},
#  {'activatedStake': 86548271720349,
#   'commission': 10,
#   'epochCredits': [[340, 10232618, 9880615],
#    [341, 10586361, 10232618],
#    [342, 10971469, 10586361],
#    [343, 11343143, 10971469],
#    [344, 11345521, 11343143]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'b8ThsbsARWyjqWrBdU9JNFhXg8ZAjDaJtaqXXzy1sRS',
#   'rootSlot': 148610866,
#   'votePubkey': 'CzmqDuqEpfnkptuLAcikmJrhCnhFXo8aUBj6Rto1SPAc'},
#  {'activatedStake': 73190355836438,
#   'commission': 10,
#   'epochCredits': [[340, 39254719, 38887911],
#    [341, 39604815, 39254719],
#    [342, 39990167, 39604815],
#    [343, 40361492, 39990167],
#    [344, 40363858, 40361492]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '8fp2i8jhVcspsXUcHMQAnfQknT9nmuxFASdv6kV2FkwU',
#   'rootSlot': 148610869,
#   'votePubkey': 'Cc7UtVq4G25VbC3w6Ccs2XL2xikjc926q1sHp8zfddoL'},
#  {'activatedStake': 73480621904809,
#   'commission': 10,
#   'epochCredits': [[340, 76524773, 76157541],
#    [341, 76877215, 76524773],
#    [342, 77262339, 76877215],
#    [343, 77629563, 77262339],
#    [344, 77631918, 77629563]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '7ek3CDbxpGRdCVTJJpj6WPHmZrJqBCQ2RBQoqLHitx5L',
#   'rootSlot': 148610866,
#   'votePubkey': '3Dm1Adr8LzNsb1QrVmTxgdgqC6tHMiR4mw2fY2t1ZfBu'},
#  {'activatedStake': 72364323871760,
#   'commission': 10,
#   'epochCredits': [[340, 14967978, 14600292],
#    [341, 15320775, 14967978],
#    [342, 15705639, 15320775],
#    [343, 16072637, 15705639],
#    [344, 16074990, 16072637]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '5spfmL3ZksWzAdAoKE5VzUuQKW5R3CwxbJYBJBymXYMH',
#   'rootSlot': 148610863,
#   'votePubkey': 'CQr9DJLMeYqmXcfG8Z8cgSFw7ntXvVUamBM3dMVzWiJz'},
#  {'activatedStake': 90694959951587,
#   'commission': 10,
#   'epochCredits': [[340, 59641462, 59270661],
#    [341, 59999308, 59641462],
#    [342, 60387178, 59999308],
#    [343, 60762929, 60387178],
#    [344, 60765328, 60762929]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '2RwFJJkhr4tCTuQnZN1CFpAtn5s9pTzakagvu326W1FT',
#   'rootSlot': 148610867,
#   'votePubkey': 'HQbdXrLm3EuFyu66mCpDS4ir9zRkhNHJVnck4vxG7jEo'},
#  {'activatedStake': 45003045429240,
#   'commission': 100,
#   'epochCredits': [[340, 30477764, 30113874],
#    [341, 30831172, 30477764],
#    [342, 31216275, 30831172],
#    [343, 31588354, 31216275],
#    [344, 31590732, 31588354]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': 'JBAGscXeebsHCh6Lcoq4LN7svW3h3BJ9GKzXSEJqxZ3g',
#   'rootSlot': 148610866,
#   'votePubkey': 'GeNA3d7npeuReW3gke1USVm4Qm3qL8xEZhbbTmSGWVkZ'},
#  {'activatedStake': 73031667438756,
#   'commission': 10,
#   'epochCredits': [[340, 28205560, 27838842],
#    [341, 28558555, 28205560],
#    [342, 28942673, 28558555],
#    [343, 29311842, 28942673],
#    [344, 29314220, 29311842]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'Fk4Ujj67oY2UpSGEZtZvNi4FbcVs13gF9EG6fdqCsxTF',
#   'rootSlot': 148610866,
#   'votePubkey': '49ZngioxLzpTpNmiKzHDCWz6n8MLDc2mKUaDdtqcpdvY'},
#  {'activatedStake': 72702385383364,
#   'commission': 10,
#   'epochCredits': [[340, 87227759, 86863159],
#    [341, 87576784, 87227759],
#    [342, 87959633, 87576784],
#    [343, 88321851, 87959633],
#    [344, 88324199, 88321851]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'D2RV1q6FgePVVjrMa7AMzVbvvAeg5oS7TAV7qdNKSDsX',
#   'rootSlot': 148610867,
#   'votePubkey': 'CCxSNvJogH6LWyoiEbG7JfcWybw2FqqCExs5GuemChGr'},
#  {'activatedStake': 86019651585785,
#   'commission': 10,
#   'epochCredits': [[340, 30148807, 29781415],
#    [341, 30502454, 30148807],
#    [342, 30888071, 30502454],
#    [343, 31256502, 30888071],
#    [344, 31258892, 31256502]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'Bqg1G3BGUcJcLSt7PR56k64yxogJVa9utyZMdh7ouhV7',
#   'rootSlot': 148610867,
#   'votePubkey': '5zZ2efi44U8NV13gJuGfxXCPt4xBjv9bqiuqa1nRDsMn'},
#  {'activatedStake': 73453202893018,
#   'commission': 10,
#   'epochCredits': [[340, 41353344, 40991806],
#    [341, 41701397, 41353344],
#    [342, 42083909, 41701397],
#    [343, 42450716, 42083909],
#    [344, 42453082, 42450716]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': 'CptNqx18G3PjTz2dEq8GyU6TtTGfd31TE87mH6y5cRHT',
#   'rootSlot': 148610868,
#   'votePubkey': '3ckBi9tmx1EEnTrSF9xaK9HRusjNnckEsExD3x8xfagJ'},
#  {'activatedStake': 73572656955835,
#   'commission': 10,
#   'epochCredits': [[340, 48476406, 48108713],
#    [341, 48830326, 48476406],
#    [342, 49215594, 48830326],
#    [343, 49586591, 49215594],
#    [344, 49588970, 49586591]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'BnFVY6zedcbWvFAKa2976xNAkzyHnDQp21T6Xt3BAter',
#   'rootSlot': 148610867,
#   'votePubkey': '7GekE3x31ArGMZWxoSWyvguTogCQkrhm9isdjMRGWwL6'},
#  {'activatedStake': 202139952961703,
#   'commission': 100,
#   'epochCredits': [[340, 42722469, 42354780],
#    [341, 43075191, 42722469],
#    [342, 43460571, 43075191],
#    [343, 43832012, 43460571],
#    [344, 43834376, 43832012]],
#   'epochVoteAccount': True,
#   'lastVote': 148610895,
#   'nodePubkey': 'DQv4kTzChg7HcSoMtUxxmkMME1Z277iSen4YKE5KjpoD',
#   'rootSlot': 148610863,
#   'votePubkey': 'BWjYF7ZX8b7Hbj1VHKJVPvdGmxdh59psWotJb7pLBAUZ'},
#  {'activatedStake': 73444616940456,
#   'commission': 10,
#   'epochCredits': [[340, 43929314, 43561192],
#    [341, 44283464, 43929314],
#    [342, 44668632, 44283464],
#    [343, 45038108, 44668632],
#    [344, 45040482, 45038108]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '5t9Vm2BYX4ZVnQmwq6Pa4trqJLWtrNmSjE5ErC9gjtVm',
#   'rootSlot': 148610863,
#   'votePubkey': '7PHYfBQAdbbHXvQCbdLPgnkXofDyPx1pkSjkf7GyYer9'},
#  {'activatedStake': 72892092903348,
#   'commission': 10,
#   'epochCredits': [[340, 30663633, 30299728],
#    [341, 31013107, 30663633],
#    [342, 31395995, 31013107],
#    [343, 31762383, 31395995],
#    [344, 31764716, 31762383]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': '6m5vsg6XfsVUroo1zzZmB4YgFmV6ykLiwEXb6choovpc',
#   'rootSlot': 148610863,
#   'votePubkey': '8gJCfKzr55gM6DtAaFqoWjBGAmsJ71mpHem6qJAASBU4'},
#  {'activatedStake': 73028631154016,
#   'commission': 10,
#   'epochCredits': [[340, 35278596, 34911669],
#    [341, 35632091, 35278596],
#    [342, 36017179, 35632091],
#    [343, 36385900, 36017179],
#    [344, 36388271, 36385900]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'Brd4kFdr4QpbMJ8Vj3LUmPJ19JTVvWdRi3xMrkCtbNKA',
#   'rootSlot': 148610863,
#   'votePubkey': '8MWWo5WUBk1UPUAvCrRMqok41rktkesmhpDmofJNRT7S'},
#  {'activatedStake': 73453110033151,
#   'commission': 10,
#   'epochCredits': [[340, 46409340, 46042287],
#    [341, 46762995, 46409340],
#    [342, 47147672, 46762995],
#    [343, 47516453, 47147672],
#    [344, 47518825, 47516453]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '7LMg8n5DRe5UzSH1Qyn7say9HQshWjjnaURMBaNgxCYE',
#   'rootSlot': 148610867,
#   'votePubkey': 'H6K5BVvhQoShyjYKG9yHAMU1WCgv6GLrgwHBLPpHvimA'},
#  {'activatedStake': 73509820142659,
#   'commission': 10,
#   'epochCredits': [[340, 75980096, 75613080],
#    [341, 76332815, 75980096],
#    [342, 76717831, 76332815],
#    [343, 77082144, 76717831],
#    [344, 77084539, 77082144]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '692qK4TkXnrGfDZfoSq9aFfnoE2WNW5TpMRnN7M3sumF',
#   'rootSlot': 148610867,
#   'votePubkey': 'FpEPW2mhwkWobuzAeamPokAhoi731bkiLXXrptFiXTSR'},
#  {'activatedStake': 73529740820311,
#   'commission': 10,
#   'epochCredits': [[340, 49809783, 49441551],
#    [341, 50163841, 49809783],
#    [342, 50549108, 50163841],
#    [343, 50919895, 50549108],
#    [344, 50922251, 50919895]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'wx63uSaK3UtXLDJLCwv1Y2WHSdpGY3znwhkGpr5n2if',
#   'rootSlot': 148610869,
#   'votePubkey': '5XTHE6UMaVVS5maayoGkW924gjzZrkkp5h4hi6ZSnps5'},
#  {'activatedStake': 89834300302301,
#   'commission': 10,
#   'epochCredits': [[340, 5464405, 5096740],
#    [341, 5817481, 5464405],
#    [342, 6199001, 5817481],
#    [343, 6570589, 6199001],
#    [344, 6572993, 6570589]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '5MEXHirS353UM59bVh7ed22tJC6ftwmhkdBxJpmMz3kR',
#   'rootSlot': 148610867,
#   'votePubkey': 'CZw1sSfjZbCccsk2kTjbFeVSgfzEgV1JxHEsEW69Qce9'},
#  {'activatedStake': 73576681128658,
#   'commission': 10,
#   'epochCredits': [[340, 43466154, 43102315],
#    [341, 43815893, 43466154],
#    [342, 44197213, 43815893],
#    [343, 44566433, 44197213],
#    [344, 44568796, 44566433]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'AFMBF53SRVTdXGe2FUKQ36JWGNGbDcFLDU3L9HsrmMxh',
#   'rootSlot': 148610867,
#   'votePubkey': '82n1Pd5fSmmTBXuRfuaXbaKYkT6EnzA6PaZwFRGs83cB'},
#  {'activatedStake': 71758540477343,
#   'commission': 10,
#   'epochCredits': [[340, 23813017, 23447161],
#    [341, 24165821, 23813017],
#    [342, 24548292, 24165821],
#    [343, 24918611, 24548292],
#    [344, 24921011, 24918611]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '13442mSWLHjWwz3A39qjDEZzZR1jUWKNzgphNBsrS7xy',
#   'rootSlot': 148610863,
#   'votePubkey': '5Z22axo39jZEA3x7x9A6AMVaqvgBvtSxo5PpbRf92sh'},
#  {'activatedStake': 72989781674633,
#   'commission': 10,
#   'epochCredits': [[340, 18299495, 17932297],
#    [341, 18652841, 18299495],
#    [342, 19037753, 18652841],
#    [343, 19406856, 19037753],
#    [344, 19409218, 19406856]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '5d385bnt7MQUfDmGaps74MJt7WddpsgKCo6aQZMtnGNP',
#   'rootSlot': 148610867,
#   'votePubkey': '3nSx5yrMimosm6fWh3KooRp6RxAr2A81o7UAgZUhuLQc'},
#  {'activatedStake': 72375946424175,
#   'commission': 10,
#   'epochCredits': [[340, 22805660, 22449756],
#    [341, 23158693, 22805660],
#    [342, 23543590, 23158693],
#    [343, 23914878, 23543590],
#    [344, 23917235, 23914878]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '3fiZs7R4LfPCPnGuKRWAjTgAZ8t5crPTCGtfku7fPPCw',
#   'rootSlot': 148610867,
#   'votePubkey': 'D8JseWSLBgcim3yMKe2gvbNCkZ4x7PYcGVrXxJVG5JqU'},
#  {'activatedStake': 26065259159065,
#   'commission': 4,
#   'epochCredits': [[340, 12935238, 12568379],
#    [341, 13285374, 12935238],
#    [342, 13668456, 13285374],
#    [343, 14037733, 13668456],
#    [344, 14040085, 14037733]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'WUw4GjpxhwDJo2CFevNuveYT2VV7CxpQqbJYXXTkYx3',
#   'rootSlot': 148610867,
#   'votePubkey': 'BhbX6orFDZ9G6t3m4oSbLyW5fQNFGpjmTxgh7BraCBus'},
#  {'activatedStake': 86652566062484,
#   'commission': 7,
#   'epochCredits': [[340, 9742111, 9374416],
#    [341, 10096250, 9742111],
#    [342, 10481854, 10096250],
#    [343, 10853990, 10481854],
#    [344, 10856384, 10853990]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '9BqiQe8pLksxHhAgGnoPnh7nrvrmL8Bbud7DJxRzhv6U',
#   'rootSlot': 148610869,
#   'votePubkey': 'HdJ6mGGfz8FXPXUyVMXRMhaQ5vUiFswQUw64for5pyjb'},
#  {'activatedStake': 72904044495605,
#   'commission': 10,
#   'epochCredits': [[340, 29229642, 28870764],
#    [341, 29577806, 29229642],
#    [342, 29955754, 29577806],
#    [343, 30325576, 29955754],
#    [344, 30327943, 30325576]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '5UrytXFCG2zh3YRQGTwc61oY1iLA6QitMAidhuku6Mgf',
#   'rootSlot': 148610867,
#   'votePubkey': '8zCJw6dETsPGCCkre459fDoM4YjK6BCVqqfSyyhRXtaT'},
#  {'activatedStake': 73465320219831,
#   'commission': 10,
#   'epochCredits': [[340, 51202196, 50834025],
#    [341, 51556286, 51202196],
#    [342, 51941197, 51556286],
#    [343, 52310867, 51941197],
#    [344, 52313257, 52310867]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'DsfrDeLSNgvphTCiPD5aMh35Wk3asm2GBHMeZDZ2Wzdd',
#   'rootSlot': 148610867,
#   'votePubkey': 'ErEqDD2DHyDPrrHW8Z4f6MEvTHfQvSPCT8AH3D2PuE1p'},
#  {'activatedStake': 101578885280026,
#   'commission': 10,
#   'epochCredits': [[340, 50347492, 49980027],
#    [341, 50701590, 50347492],
#    [342, 51086981, 50701590],
#    [343, 51458839, 51086981],
#    [344, 51461222, 51458839]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '61QB1Evn9E3noQtpJm4auFYyHSXS5FPgqKtPgwJJfEQk',
#   'rootSlot': 148610863,
#   'votePubkey': '5iZ5PQPy5Z9XDnkfoWPi6nvUgtxWnRFwZ36WaftPuaVM'},
#  {'activatedStake': 74174801469007,
#   'commission': 10,
#   'epochCredits': [[340, 72459403, 72092562],
#    [341, 72812907, 72459403],
#    [342, 73198085, 72812907],
#    [343, 73566054, 73198085],
#    [344, 73568417, 73566054]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'BPX9WVx1MjVpSWY9fo3hGXfE74yKXcreS2XYKjpiyJfZ',
#   'rootSlot': 148610867,
#   'votePubkey': '26WLNWKrYSyPkQF2NU9LgLSRXGiXWjhPnvspG8ibFh63'},
#  {'activatedStake': 64971069235168,
#   'commission': 5,
#   'epochCredits': [[340, 30829696, 30461180],
#    [341, 31183758, 30829696],
#    [342, 31549294, 31183758],
#    [343, 31920908, 31549294],
#    [344, 31923273, 31920908]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': '5N9r2ne7dPgHtzeHC5ETJ3DAueKQiXSU8KAmEZrrojT7',
#   'rootSlot': 148610865,
#   'votePubkey': 'H7fXvnLCKtZqJBTipxeseabGfAZUdHJ9XuP6hCKrbvUb'},
#  {'activatedStake': 72901896978880,
#   'commission': 10,
#   'epochCredits': [[340, 29127807, 28762468],
#    [341, 29481106, 29127807],
#    [342, 29866386, 29481106],
#    [343, 30237846, 29866386],
#    [344, 30240219, 30237846]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '6bdb3cRscVm1HTNNvgR8bumjSsQd2fbuFjwANtCLHC8f',
#   'rootSlot': 148610867,
#   'votePubkey': 'DeFiDeAgFR29GgKdyyVZdvsELbDR8k4WqprWGtgtbi1o'},
#  {'activatedStake': 71756007924828,
#   'commission': 10,
#   'epochCredits': [[340, 11490922, 11123450],
#    [341, 11844747, 11490922],
#    [342, 12229303, 11844747],
#    [343, 12598353, 12229303],
#    [344, 12600718, 12598353]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '2EiEMRvsBS43gbDCi5yb9GfRBghae41UFAbBt2iSvNYB',
#   'rootSlot': 148610867,
#   'votePubkey': '6tajb2FFdjiRJLrdwfKQsijHGmeVFcTcXJn6NH3BEoLW'},
#  {'activatedStake': 71756066388897,
#   'commission': 10,
#   'epochCredits': [[340, 6229420, 5861463],
#    [341, 6582370, 6229420],
#    [342, 6967621, 6582370],
#    [343, 7338912, 6967621],
#    [344, 7341284, 7338912]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '7nZggPGgUh6bt1pTrYLa4GqrL8uUSwpSDnzQdMcLXJ1r',
#   'rootSlot': 148610863,
#   'votePubkey': 'A1PLVxBzMDRiEX3HN2gKZ5kGa4Mvq645UWV7uqrijkA1'},
#  {'activatedStake': 92828859078826,
#   'commission': 10,
#   'epochCredits': [[340, 88606406, 88241813],
#    [341, 88958237, 88606406],
#    [342, 89341999, 88958237],
#    [343, 89712397, 89341999],
#    [344, 89714770, 89712397]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '2KnfYVJiAtxiSPfHYRzTsGGhUAhDTNrJXWn7n6K6giJU',
#   'rootSlot': 148610863,
#   'votePubkey': 'BUTBf3nPUdD8zEKSqZgpHzYqpzPc74ueXaGMBkVAe19U'},
#  {'activatedStake': 78058791652854,
#   'commission': 10,
#   'epochCredits': [[340, 82963418, 82599166],
#    [341, 83312416, 82963418],
#    [342, 83694985, 83312416],
#    [343, 84059063, 83694985],
#    [344, 84061407, 84059063]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': 'CsqwHrSUAWsWpN5kUcjcv4Nsq5JtgFiDJTckaY1zuXPf',
#   'rootSlot': 148610866,
#   'votePubkey': '8Dfm249TXe9Wd3wYEnpBdSme659gecoEMH8zx1YWN79v'},
#  {'activatedStake': 72905549699599,
#   'commission': 10,
#   'epochCredits': [[340, 35287103, 34920291],
#    [341, 35641086, 35287103],
#    [342, 36026176, 35641086],
#    [343, 36396147, 36026176],
#    [344, 36398521, 36396147]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'L5navwB5bnXmVVEC4YQ6H4WwFp4oBd8LJMCUvSEwsT9',
#   'rootSlot': 148610869,
#   'votePubkey': 'HRVgnAc1LgUZ46rGumSbMUpiqbHPdw3RhzKF6GapMTyi'},
#  {'activatedStake': 72064056298009,
#   'commission': 10,
#   'epochCredits': [[340, 11202570, 10840598],
#    [341, 11551444, 11202570],
#    [342, 11934483, 11551444],
#    [343, 12298778, 11934483],
#    [344, 12301121, 12298778]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': 'D6AjfG1PzzzDAubmVoqH4iFHDSvwJbMmPNByvK9jdYRm',
#   'rootSlot': 148610866,
#   'votePubkey': '6xyYaQaRwM2XtKykicXL7FdrtBqpxWQs1UsjQhcC1Uqy'},
#  {'activatedStake': 73451222678292,
#   'commission': 10,
#   'epochCredits': [[340, 86717847, 86353520],
#    [341, 87067569, 86717847],
#    [342, 87450422, 87067569],
#    [343, 87816750, 87450422],
#    [344, 87819091, 87816750]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '2mKEUVkcttHeMeaZK8jjwkuwGSdCBm23xDgzXgbhTdPe',
#   'rootSlot': 148610866,
#   'votePubkey': 'EoMcV8x78aGZYN3RSW8xk311Q8xKNHMXF94UJaEzsMoW'},
#  {'activatedStake': 72069476066580,
#   'commission': 10,
#   'epochCredits': [[340, 5870117, 5502790],
#    [341, 6224221, 5870117],
#    [342, 6609695, 6224221],
#    [343, 6979451, 6609695],
#    [344, 6981810, 6979451]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'CAU6KrM4eQ3L74y9RhUshT5VGUz4R41YsdEpxBB3HAyJ',
#   'rootSlot': 148610866,
#   'votePubkey': 'DaPBtYGAC3Pabq5JmDEM8pDsbP6GbbbGn862vQiwim1w'},
#  {'activatedStake': 72668675702502,
#   'commission': 10,
#   'epochCredits': [[340, 24005120, 23646205],
#    [341, 24354208, 24005120],
#    [342, 24732631, 24354208],
#    [343, 25097426, 24732631],
#    [344, 25099765, 25097426]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '4gP3BzB4wYiHYkatrbJQAhTM8ysgFfiNSFwmNth8b34D',
#   'rootSlot': 148610863,
#   'votePubkey': 'JChWyNsSR66yf5Z7NbSZWgJ8xoj8JGymLHpEm2NpoHRR'},
#  {'activatedStake': 1435084571906792,
#   'commission': 8,
#   'epochCredits': [[340, 118112433, 117744877],
#    [341, 118462606, 118112433],
#    [342, 118847155, 118462606],
#    [343, 119219064, 118847155],
#    [344, 119221429, 119219064]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'fishfishrD9BwrQQiAcG6YeYZVUYVJf3tb9QGQPMJqF',
#   'rootSlot': 148610863,
#   'votePubkey': '7VGU4ZwR1e1AFekqbqv2gvjeg47e1PwMPm4BfLt6rxNk'},
#  {'activatedStake': 73442703202757,
#   'commission': 10,
#   'epochCredits': [[340, 76441629, 76074289],
#    [341, 76792556, 76441629],
#    [342, 77177626, 76792556],
#    [343, 77544590, 77177626],
#    [344, 77546946, 77544590]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '42xkjBQvPyicSdCET8eTWwJayTBofFLGWyCiuodd1SoT',
#   'rootSlot': 148610867,
#   'votePubkey': 'B4H6ZdnJ8YisoYJdbkRjzt9uE5uRSpVqiFGBK9fHNugk'},
#  {'activatedStake': 86108839491624,
#   'commission': 10,
#   'epochCredits': [[340, 28913613, 28549381],
#    [341, 29263910, 28913613],
#    [342, 29646882, 29263910],
#    [343, 30013058, 29646882],
#    [344, 30015390, 30013058]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '4vnAeQfvoPomQ3KuCXvFb9nk5jbWNRzjpJq1Pmo3rHUb',
#   'rootSlot': 148610866,
#   'votePubkey': '46CeeJesHY7Yca4kZBJuEdDd6iN1iHQV6MnUYps2C3va'},
#  {'activatedStake': 160959886285,
#   'commission': 10,
#   'epochCredits': [[341, 4590, 0],
#    [342, 384637, 4590],
#    [343, 747957, 384637],
#    [344, 750292, 747957]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '4vcL2ZGwwX2Jhi9dCgpUhxAS8EkVQu7fDaEebQXHZGsV',
#   'rootSlot': 148610867,
#   'votePubkey': '3GrJKm6zQwmtyEfKNr8BBDapmsCpBuo2WPJa3Eb8AQiM'},
#  {'activatedStake': 1270345919001649,
#   'commission': 4,
#   'epochCredits': [[340, 16088592, 15719978],
#    [341, 16442801, 16088592],
#    [342, 16828051, 16442801],
#    [343, 17199700, 16828051],
#    [344, 17202090, 17199700]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': '32G1W4XLPcPBw9goEg5WyYoq5LS9kK63uRVMeRsPFjDf',
#   'rootSlot': 148610863,
#   'votePubkey': 'Eb1oa4AfSUb5bHrKnNdSkZwjoAofMcLnkF7LgYBAyfsY'},
#  {'activatedStake': 73019210729931,
#   'commission': 10,
#   'epochCredits': [[340, 36234076, 35868352],
#    [341, 36586201, 36234076],
#    [342, 36969724, 36586201],
#    [343, 37338719, 36969724],
#    [344, 37341071, 37338719]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'AckA1VJrq9e17pdCMwK23NHhxVMBPGFdZVCeCcguSWMW',
#   'rootSlot': 148610863,
#   'votePubkey': '8RWnrqVrZXXckoqfXz41uvzmbtREeLFaAquRwq3yQAd1'},
#  {'activatedStake': 83879029253061,
#   'commission': 10,
#   'epochCredits': [[340, 76153880, 75789906],
#    [341, 76502988, 76153880],
#    [342, 76886183, 76502988],
#    [343, 77252994, 76886183],
#    [344, 77255326, 77252994]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '2pRZBEB1PX12cBAbgh58VfzTPV4ePJ3txXeDTM84ejbZ',
#   'rootSlot': 148610863,
#   'votePubkey': 'CDVkS2zVVHqiADfap8W3Mb6ZMm4KUKg4igE8axtHqFKT'},
#  {'activatedStake': 72897807101206,
#   'commission': 10,
#   'epochCredits': [[340, 33103820, 32736996],
#    [341, 33440120, 33103820],
#    [342, 33824821, 33440120],
#    [343, 34194429, 33824821],
#    [344, 34196826, 34194429]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'Dhs6P4kjtszfhaLeZGbVZrFgPcimgQ91SGZXkAxcx1tp',
#   'rootSlot': 148610867,
#   'votePubkey': 'CpVuHak8A6nBezvG1EEq6YiUC8nfEcy5MdjxNmiUgRwj'},
#  {'activatedStake': 70795874181680,
#   'commission': 10,
#   'epochCredits': [[340, 44554064, 44186761],
#    [341, 44907535, 44554064],
#    [342, 45282514, 44907535],
#    [343, 45649334, 45282514],
#    [344, 45651708, 45649334]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '4ZRq7rNhvo1UJEVhz8Sez5nugQVpJRPd5Bqeq9t9RvtV',
#   'rootSlot': 148610869,
#   'votePubkey': '7YzmMGQhrE7VaTiDFnb7R633gquLEKmSpwkXG6u64fhj'},
#  {'activatedStake': 73446624382883,
#   'commission': 10,
#   'epochCredits': [[340, 49481599, 49117321],
#    [341, 49829982, 49481599],
#    [342, 50214899, 49829982],
#    [343, 50582490, 50214899],
#    [344, 50584888, 50582490]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'FnE1mgYTPujN7iNHvGrFLYSXje48hzsGF9jFNKknj2bM',
#   'rootSlot': 148610867,
#   'votePubkey': 'DHasctf9Gs2hRY2QzSoRiLuJnuEkRcGHSrh2JUxthxwa'},
#  {'activatedStake': 73026881059235,
#   'commission': 10,
#   'epochCredits': [[340, 33199880, 32832376],
#    [341, 33553336, 33199880],
#    [342, 33938436, 33553336],
#    [343, 34307954, 33938436],
#    [344, 34310335, 34307954]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '5Ub62TBgcTqYzD6jCQv97kAbBPGASHLJTkpDP4GeHgTR',
#   'rootSlot': 148610867,
#   'votePubkey': 'EJC8q8MGpifkXGE1VdvH5kJmnA4bAi28gTEdF54ew9rk'},
#  {'activatedStake': 72684390691211,
#   'commission': 10,
#   'epochCredits': [[340, 21133071, 20783743],
#    [341, 21486324, 21133071],
#    [342, 21871013, 21486324],
#    [343, 22242814, 21871013],
#    [344, 22245203, 22242814]],
#   'epochVoteAccount': True,
#   'lastVote': 148610895,
#   'nodePubkey': '9E66AGL6BCLsmhGfKA7Xh2waZ6A2EQ1JCbabmpKcvyk6',
#   'rootSlot': 148610863,
#   'votePubkey': '6zvpPt26s3abg8SSj5qNbfevsGnWXubanXFx7UdxoKai'},
#  {'activatedStake': 71439592879682,
#   'commission': 10,
#   'epochCredits': [[340, 5460355, 5092604],
#    [341, 5801625, 5460355],
#    [342, 6186931, 5801625],
#    [343, 6548784, 6186931],
#    [344, 6551130, 6548784]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '7XoQn2CHHpCjc7owZozCysu5NJGUj8AX7A5hoKRxMzGW',
#   'rootSlot': 148610867,
#   'votePubkey': '88GrXE71Kn7oxrptCy8bgmQHBwVhxXz9EGwZ981N3j2Z'},
#  {'activatedStake': 83432737054477,
#   'commission': 10,
#   'epochCredits': [[340, 11655324, 11287228],
#    [341, 12008763, 11655324],
#    [342, 12393776, 12008763],
#    [343, 12762788, 12393776],
#    [344, 12765144, 12762788]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'HEbc38jMRaj5j64jNhm8ttu7k2CJvvy2KNrtaR26fv95',
#   'rootSlot': 148610866,
#   'votePubkey': '9xVJXRz6ndVh1gbSFa8wirWkttb8ffgvhAd7k26yRpKQ'},
#  {'activatedStake': 73451530476101,
#   'commission': 10,
#   'epochCredits': [[340, 40505248, 40140226],
#    [341, 40854665, 40505248],
#    [342, 41237992, 40854665],
#    [343, 41601964, 41237992],
#    [344, 41604318, 41601964]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '8gbW5yX5kvsE5TkNBJpoQPoasj9UWYJfTQMvUCgxzxuY',
#   'rootSlot': 148610867,
#   'votePubkey': 'DtxirJvtXH4HqMJ7YJ9MN1WaJrokdmS76MCHGDJTeepM'},
#  {'activatedStake': 80420962356219,
#   'commission': 10,
#   'epochCredits': [[340, 63833201, 63468950],
#    [341, 64182417, 63833201],
#    [342, 64565180, 64182417],
#    [343, 64928100, 64565180],
#    [344, 64930467, 64928100]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '6mdtNmZpSycAZKXKy9JkkfdEZCMcnuyuA7fzdnpUohZr',
#   'rootSlot': 148610867,
#   'votePubkey': '9TUJdBxnHvAapYoq8cVFgh1bMbTh6GYfY4etDqWVKXAT'},
#  {'activatedStake': 72384291576937,
#   'commission': 10,
#   'epochCredits': [[340, 8904600, 8540171],
#    [341, 9254036, 8904600],
#    [342, 9636974, 9254036],
#    [343, 10004438, 9636974],
#    [344, 10006780, 10004438]],
#   'epochVoteAccount': True,
#   'lastVote': 148610905,
#   'nodePubkey': '8mgNRA1bz3Fu8H3ykXXFhka4nYNdezxpWHWGCmZnm4Tq',
#   'rootSlot': 148610866,
#   'votePubkey': 'DRsPkCHqXCmKz64nVgjvK6Vr121GuzVUuShD49wUN22t'},
#  {'activatedStake': 72888788691276,
#   'commission': 10,
#   'epochCredits': [[340, 34827342, 34459387],
#    [341, 35180734, 34827342],
#    [342, 35565656, 35180734],
#    [343, 35934366, 35565656],
#    [344, 35936726, 35934366]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'J8yuUUBEL1T1LKmWA9WCUgroEyhJP7AsA4GQMxtNuDUy',
#   'rootSlot': 148610867,
#   'votePubkey': 'EeU5AomrKqXj8kq2SrSfzYv33Gczph6jd2NBQEw4HsES'},
#  {'activatedStake': 73452835258899,
#   'commission': 10,
#   'epochCredits': [[340, 70371069, 70008205],
#    [341, 70720509, 70371069],
#    [342, 71103224, 70720509],
#    [343, 71471824, 71103224],
#    [344, 71474156, 71471824]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'GosJ8GHbSUunTQPY5xEyjhY2Eg5a9qSuPhNC4Ctztr7y',
#   'rootSlot': 148610866,
#   'votePubkey': 'DHXbmu3KUhHYn2Trned5ZUaGC6GRgHYhJoRbCr75XQxj'},
#  {'activatedStake': 85283241893220,
#   'commission': 10,
#   'epochCredits': [[340, 29932949, 29567954],
#    [341, 30283165, 29932949],
#    [342, 30665937, 30283165],
#    [343, 31032463, 30665937],
#    [344, 31034813, 31032463]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'CyLV3N5Z4y5ZizuL7fJEH8EKmtdNdjBvUrYJGeDwKA92',
#   'rootSlot': 148610869,
#   'votePubkey': 'FSYHzW1f7XmFS6KcbciQecGkWUzajXMsVcHz8Egd8SoZ'},
#  {'activatedStake': 161046520836,
#   'commission': 10,
#   'epochCredits': [[341, 9100, 0],
#    [342, 389216, 9100],
#    [343, 760822, 389216],
#    [344, 763202, 760822]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'Bqprt92P5HRh2p534ZH7TquWPKKW5q4wBNxpTDTHBg8c',
#   'rootSlot': 148610867,
#   'votePubkey': '9wVjftGcMLxfnjDc4vKUcHofF64JiRxFNFxHzrKwGkSL'},
#  {'activatedStake': 80898951061631,
#   'commission': 10,
#   'epochCredits': [[340, 46345885, 45978343],
#    [341, 46699472, 46345885],
#    [342, 47084890, 46699472],
#    [343, 47453534, 47084890],
#    [344, 47455899, 47453534]],
#   'epochVoteAccount': True,
#   'lastVote': 148610895,
#   'nodePubkey': 'FSq3EXWdLvUDBVgZ47joponPRq12NRUfXoCwZbeL9Eh',
#   'rootSlot': 148610863,
#   'votePubkey': 'FyFUiXY9JLFp2iPxvy3Jkv2BVcyEN39RDrJngTPLZ62L'},
#  {'activatedStake': 68592991570705,
#   'commission': 10,
#   'epochCredits': [[340, 48664306, 48296678],
#    [341, 49012733, 48664306],
#    [342, 49317160, 49012733],
#    [343, 49620346, 49317160],
#    [344, 49622695, 49620346]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': 'FLWc77X8dKh5RdJe5xMFxry8kvSVUbo9G4MQ8hCAg5ve',
#   'rootSlot': 148610865,
#   'votePubkey': 'EcZBjDPzSZLdsyKCBq26MZMYFfiinZsfcL3SwWMK1eNL'},
#  {'activatedStake': 43872865388963,
#   'commission': 10,
#   'epochCredits': [[340, 30415410, 30050303],
#    [341, 30759246, 30415410],
#    [342, 31138683, 30759246],
#    [343, 31492411, 31138683],
#    [344, 31494797, 31492411]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '7LuMjj1j7KjGXBi3TwnNGnXnENK5rjMuLxpcRPVqjsp1',
#   'rootSlot': 148610867,
#   'votePubkey': '5KgAGvMLZogKnDGKGgn47xY6GaTwQ3WBbGPoBxW5nDqp'},
#  {'activatedStake': 73007403303132,
#   'commission': 10,
#   'epochCredits': [[340, 17732049, 17367524],
#    [341, 18081552, 17732049],
#    [342, 18464112, 18081552],
#    [343, 18828994, 18464112],
#    [344, 18831329, 18828994]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '6wARr6hLphghdkFJJZj7MNKGtcJaF4bV8WEB2qToccYg',
#   'rootSlot': 148610863,
#   'votePubkey': '257RiTszC98omSCmX9KjNMwDDhiceGPcHtPyzC184D8R'},
#  {'activatedStake': 72064294830966,
#   'commission': 10,
#   'epochCredits': [[340, 23009455, 22641649],
#    [341, 23362743, 23009455],
#    [342, 23747524, 23362743],
#    [343, 24114618, 23747524],
#    [344, 24117001, 24114618]],
#   'epochVoteAccount': True,
#   'lastVote': 148610895,
#   'nodePubkey': 'J9GZMuGa6LMDW6wMRerpkv2myqPnjNGSaRB5Z3KsNi3f',
#   'rootSlot': 148610863,
#   'votePubkey': '77hUX7gpQov27qQTBDyJKJXNwm7apatfhEdsStC3YUb8'},
#  {'activatedStake': 73446355721237,
#   'commission': 10,
#   'epochCredits': [[340, 64140162, 63772604],
#    [341, 64492950, 64140162],
#    [342, 64878300, 64492950],
#    [343, 65247726, 64878300],
#    [344, 65250074, 65247726]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'GWccEztr4AFmiMvvvXcib4feDZXCi6U13XrxponUHFWC',
#   'rootSlot': 148610867,
#   'votePubkey': 'eRBjr1X7drpEprHddEyP8CLt2BjTcfQK74nF4YoMDN8'},
#  {'activatedStake': 81284827186806,
#   'commission': 10,
#   'epochCredits': [[340, 76450051, 76082138],
#    [341, 76804859, 76450051],
#    [342, 77189622, 76804859],
#    [343, 77560980, 77189622],
#    [344, 77563362, 77560980]],
#   'epochVoteAccount': True,
#   'lastVote': 148610895,
#   'nodePubkey': '67joanjyAoVmb9nZLyX8p3Gx9tAxzXaUgHDe3kaUH4wf',
#   'rootSlot': 148610863,
#   'votePubkey': '9vNLTLdwAdHw8EdiZrLzDtUpm3hp7E2MGaNi6SmdfBGz'},
#  {'activatedStake': 4507838307762690,
#   'commission': 7,
#   'epochCredits': [[340, 116723095, 116355705],
#    [341, 117077122, 116723095],
#    [342, 117462100, 117077122],
#    [343, 117833355, 117462100],
#    [344, 117835735, 117833355]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'DWvDTSh3qfn88UoQTEKRV2JnLt5jtJAVoiCo3ivtMwXP',
#   'rootSlot': 148610867,
#   'votePubkey': 'FKsC411dik9ktS6xPADxs4Fk2SCENvAiuccQHLAPndvk'},
#  {'activatedStake': 85342956863381,
#   'commission': 10,
#   'epochCredits': [[340, 45665636, 45297506],
#    [341, 46019352, 45665636],
#    [342, 46404505, 46019352],
#    [343, 46774925, 46404505],
#    [344, 46777282, 46774925]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'ANScUD8o6eqYNuqTYrrh7yuGWmuBRzaTcgiDcVbuRc4S',
#   'rootSlot': 148610869,
#   'votePubkey': '4GEaWcSfgCyKQqUJGYbDi3bqzU3zL3iGuhvNhspHouVV'},
#  {'activatedStake': 72374515263016,
#   'commission': 10,
#   'epochCredits': [[340, 30868242, 30500549],
#    [341, 31221884, 30868242],
#    [342, 31606462, 31221884],
#    [343, 31976460, 31606462],
#    [344, 31978832, 31976460]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'D8izqaR979Fc2amDoGHmYqEugjckEi1RQL1Y1JKyHUwX',
#   'rootSlot': 148610867,
#   'votePubkey': 'DHdYsTEsd1wGrmthR1ognfRXPkWBmxAWAv2pKdAix3HY'},
#  {'activatedStake': 72079702082836,
#   'commission': 10,
#   'epochCredits': [[340, 11110104, 10754622],
#    [341, 11443591, 11110104],
#    [342, 11829079, 11443591],
#    [343, 12188814, 11829079],
#    [344, 12191204, 12188814]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '5jYQbBqYpngfESdTxVe1knYvFV7MG76UoZXi7R2ycm4d',
#   'rootSlot': 148610866,
#   'votePubkey': 'EGEePZL2pmTEuxzDBewnK5Z2FQ7MjCpbunYQ7DT52mjT'},
#  {'activatedStake': 73483668563112,
#   'commission': 10,
#   'epochCredits': [[340, 47517479, 47149837],
#    [341, 47872227, 47517479],
#    [342, 48257489, 47872227],
#    [343, 48603662, 48257489],
#    [344, 48606038, 48603662]],
#   'epochVoteAccount': True,
#   'lastVote': 148610895,
#   'nodePubkey': '8XGi2KgRoUq7t7NxaS9ocRy2dkrX74LGRACFRSNX4RFW',
#   'rootSlot': 148610863,
#   'votePubkey': '6T7SEeBwdFov3vYVFt1vt7mEU1w57TbevvETqipp9DW3'},
#  {'activatedStake': 73572290655644,
#   'commission': 10,
#   'epochCredits': [[340, 76383491, 76016141],
#    [341, 76734364, 76383491],
#    [342, 77119503, 76734364],
#    [343, 77486740, 77119503],
#    [344, 77489100, 77486740]],
#   'epochVoteAccount': True,
#   'lastVote': 148610905,
#   'nodePubkey': 'FCQTtjeFK7Fj64aVDwdahfyxiG94uLnUjkmmXUq2esuf',
#   'rootSlot': 148610863,
#   'votePubkey': 'BCnjkkKPBT8cegVkFQ15B6TtonqD9d27gM5UUD6imEe9'},
#  {'activatedStake': 71438708732971,
#   'commission': 10,
#   'epochCredits': [[340, 23856387, 23491569],
#    [341, 24210223, 23856387],
#    [342, 24592545, 24210223],
#    [343, 24962525, 24592545],
#    [344, 24964915, 24962525]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'CQaFuTVTBQCcSpqjMUjdpfgeygbMPVJhobHxV5FitDFu',
#   'rootSlot': 148610867,
#   'votePubkey': '7tr5vUb3j36k4p9bs2tr1GwRFoSsEWd4LEut8e8HJZEv'},
#  {'activatedStake': 72640117333275,
#   'commission': 10,
#   'epochCredits': [[340, 15037317, 14673263],
#    [341, 15384527, 15037317],
#    [342, 15767386, 15384527],
#    [343, 16133979, 15767386],
#    [344, 16136338, 16133979]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '2kVZVTY8FMRZ3WuHzyqNz8qd4Ytbba9f9DaesUm5WLvR',
#   'rootSlot': 148610866,
#   'votePubkey': 'qx983oDJVnXRb87pDz7w1WWJgaAa8jHj8oVDTWJubo1'},
#  {'activatedStake': 73444271248101,
#   'commission': 10,
#   'epochCredits': [[340, 44617268, 44252899],
#    [341, 44965445, 44617268],
#    [342, 45348380, 44965445],
#    [343, 45713176, 45348380],
#    [344, 45715517, 45713176]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '6wAGwhyLhZPKcWd2UntykgQRhbNzv2cZU4pdeFmExrAY',
#   'rootSlot': 148610867,
#   'votePubkey': '6YhwLXrsoAF7veKQf5Wkni7Ui5ZGSuNKDGAoFCPERpfy'},
#  {'activatedStake': 72383403848727,
#   'commission': 10,
#   'epochCredits': [[340, 17796376, 17429199],
#    [341, 18149281, 17796376],
#    [342, 18534056, 18149281],
#    [343, 18904584, 18534056],
#    [344, 18906956, 18904584]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'FzQZdKnavkXGr3XJAai8rYJLhd5EB8SaG8ocAYEsdbRp',
#   'rootSlot': 148610863,
#   'votePubkey': 'BCHabhkHaa7DJwfkuf74vxJaKN4fUSBGHriGSNk5AJ46'},
#  {'activatedStake': 86932045269171,
#   'commission': 10,
#   'epochCredits': [[340, 88111617, 87743589],
#    [341, 88465068, 88111617],
#    [342, 88850425, 88465068],
#    [343, 89219839, 88850425],
#    [344, 89222216, 89219839]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'zeroT6PTAEjipvZuACTh1mbGCqTHgA6i1ped9DcuidX',
#   'rootSlot': 148610863,
#   'votePubkey': '5BAi9YGCipHq4ZcXuen5vagRQqRTVTRszXNqBZC6uBPZ'},
#  {'activatedStake': 102138609290611,
#   'commission': 10,
#   'epochCredits': [[340, 109684954, 109317261],
#    [341, 110038717, 109684954],
#    [342, 110423997, 110038717],
#    [343, 110794044, 110423997],
#    [344, 110796414, 110794044]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '9gJT69qJUibNmfnAPBgsqSmLqVxc3kxXpw1Vk7APDrso',
#   'rootSlot': 148610867,
#   'votePubkey': 'C6DEs3i448uhrsWMMnWYq7WsxkujcgADrCJQ4AMJ8ipj'},
#  {'activatedStake': 72891682550873,
#   'commission': 10,
#   'epochCredits': [[340, 26983268, 26620015],
#    [341, 27332732, 26983268],
#    [342, 27714585, 27332732],
#    [343, 28080572, 27714585],
#    [344, 28082922, 28080572]],
#   'epochVoteAccount': True,
#   'lastVote': 148610895,
#   'nodePubkey': '8yUruxoiMx5Yka1CRczh7mwSTSVbH6zbVdZqsdrwRoLH',
#   'rootSlot': 148610863,
#   'votePubkey': 'KdqhohoRV1P9qbgRexYhTgXg4jsEftGRrTvtYS7fCbA'},
#  {'activatedStake': 73468712638706,
#   'commission': 10,
#   'epochCredits': [[340, 64137122, 63772138],
#    [341, 64487198, 64137122],
#    [342, 64870193, 64487198],
#    [343, 65234541, 64870193],
#    [344, 65236903, 65234541]],
#   'epochVoteAccount': True,
#   'lastVote': 148610905,
#   'nodePubkey': 'Cu4M3yd2LfMoGhmYxKszhVH18SPgt6TQvqnE4AWjNKwd',
#   'rootSlot': 148610867,
#   'votePubkey': 'HmuQrPPXWkaAMhArBVvQRbknowKpsvDzNtSakvqt93st'},
#  {'activatedStake': 75116952841295,
#   'commission': 10,
#   'epochCredits': [[340, 75142154, 74811245],
#    [341, 75459453, 75142154],
#    [342, 75792361, 75459453],
#    [343, 76102187, 75792361],
#    [344, 76102569, 76102187]],
#   'epochVoteAccount': True,
#   'lastVote': 148610905,
#   'nodePubkey': 'EjcGVYigv2PA6MeZxRmgFot1P7eGQThFMS2Yh3cj5r2n',
#   'rootSlot': 148610866,
#   'votePubkey': 'Dn2cRSWAfQpb3NyUJ2q33t1scBLxzo8TZBAyKsWhX7zh'},
#  {'activatedStake': 180550068079772,
#   'commission': 10,
#   'epochCredits': [[340, 117557924, 117194499],
#    [341, 117907500, 117557924],
#    [342, 118289395, 117907500],
#    [343, 118656773, 118289395],
#    [344, 118659133, 118656773]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'Ev8D9dwYdfebkdLgAjwiJtCkqS882Uvrit5qN6NTeHMy',
#   'rootSlot': 148610867,
#   'votePubkey': 'BNTmegvdXzNVyc3UMTWSMSfJUryjr3fXEVErtdqrfs6y'},
#  {'activatedStake': 33458865757526,
#   'commission': 10,
#   'epochCredits': [[340, 12496837, 12142143],
#    [341, 12835457, 12496837],
#    [342, 13143013, 12835457],
#    [343, 13482431, 13143013],
#    [344, 13484805, 13482431]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '3qmEGZpEUFYxXiLU5CZjSaUy2X28oV51qVLenKEutYDe',
#   'rootSlot': 148610863,
#   'votePubkey': 'BHZCk3XnebkC7QKk6az18LBPrqgrL6HRp8bUKX9Mg46v'},
#  {'activatedStake': 73658858606793,
#   'commission': 10,
#   'epochCredits': [[340, 100928326, 100560621],
#    [341, 101281657, 100928326],
#    [342, 101666717, 101281657],
#    [343, 102035402, 101666717],
#    [344, 102037782, 102035402]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': '2LhJjdjNic2BcsRLN8opwd9KZSsabebQMnxj2PkU8ADQ',
#   'rootSlot': 148610866,
#   'votePubkey': '6mCs4Gi8L5RQ4ewnabmwCcVDQLBuvyqnaRcm5LGTciyz'},
#  {'activatedStake': 71448564208975,
#   'commission': 10,
#   'epochCredits': [[340, 2916912, 2548791],
#    [341, 3271624, 2916912],
#    [342, 3657017, 3271624],
#    [343, 4029017, 3657017],
#    [344, 4031374, 4029017]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '6eKcGmV3BTypxxH7R3u2T8tDuJXCQkTMuYSpp6MWZRhQ',
#   'rootSlot': 148610867,
#   'votePubkey': 'CTpe7FE8ovry2HY6x9cq2aHD57AfiPTFsMgwyMVRhw7g'},
#  {'activatedStake': 172626128956444,
#   'commission': 10,
#   'epochCredits': [[340, 117354401, 116986805],
#    [341, 117708068, 117354401],
#    [342, 118092774, 117708068],
#    [343, 118459672, 118092774],
#    [344, 118462053, 118459672]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': '7nYNfGS6VVxzCZmfbLGpsXYFm2LS9XRrva9hZahFmpqh',
#   'rootSlot': 148610863,
#   'votePubkey': '4nQTSgKURZexbRj4oXKwMiqwVCPobTcaTyMph728J3XR'},
#  {'activatedStake': 69003075375619,
#   'commission': 0,
#   'epochCredits': [[340, 33371247, 33006717],
#    [341, 33724180, 33371247],
#    [342, 34102223, 33724180],
#    [343, 34473177, 34102223],
#    [344, 34473906, 34473177]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '2UUvCc7Jittv489uA6gYvaA3EFu7DiBkodMneANXpxF7',
#   'rootSlot': 148610869,
#   'votePubkey': 'DujbfBa9RitWFkjhVqyV3h4rp2nsf7ikU7C484TwKShR'},
#  {'activatedStake': 72068355406147,
#   'commission': 10,
#   'epochCredits': [[340, 3076815, 2712381],
#    [341, 3425834, 3076815],
#    [342, 3808748, 3425834],
#    [343, 4174045, 3808748],
#    [344, 4176402, 4174045]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'F1hHyCzyy4SiUiCTNm2QvfytBLxM6XzyQVELfqFgM7G2',
#   'rootSlot': 148610863,
#   'votePubkey': 'GD8hEkU7tLjaX2qtztgiyCo1NCC2gieLYqMHZY3H5qBG'},
#  {'activatedStake': 68342018328074,
#   'commission': 10,
#   'epochCredits': [[340, 5056826, 4690676],
#    [341, 5402885, 5056826],
#    [342, 5787722, 5402885],
#    [343, 6158838, 5787722],
#    [344, 6161207, 6158838]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '44NtFPbVDNj6VKqhzTAkC7MTMj8HR7edsUCRkos8T898',
#   'rootSlot': 148610863,
#   'votePubkey': 'txoFqp3FjFccNA7k9ihX8aLsdAr7AtA6FsfXB9Vxhaq'},
#  {'activatedStake': 72388411828730,
#   'commission': 10,
#   'epochCredits': [[340, 13890621, 13523435],
#    [341, 14244055, 13890621],
#    [342, 14628458, 14244055],
#    [343, 14998376, 14628458],
#    [344, 15000766, 14998376]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': '8ZENvd3sBBijAWc36hMjwYBgp858rSdSCERhXzRacNqY',
#   'rootSlot': 148610866,
#   'votePubkey': '4XZv4mPwuXA6Q3qv3B913tEuu4NJLNLcNbDtzBdVTKXd'},
#  {'activatedStake': 72385337604005,
#   'commission': 10,
#   'epochCredits': [[340, 14085697, 13718080],
#    [341, 14439355, 14085697],
#    [342, 14824242, 14439355],
#    [343, 15192877, 14824242],
#    [344, 15195250, 15192877]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '61tSgpvRCATVhcsS5gyCZHdJtXEYtcGHGyUttaCHvfTa',
#   'rootSlot': 148610867,
#   'votePubkey': '2hcdPVHseafWnk8j4vFbLBS6yjR3AvKotkYwwf8Ng71o'},
#  {'activatedStake': 73571704146504,
#   'commission': 10,
#   'epochCredits': [[340, 47156146, 46788580],
#    [341, 47509722, 47156146],
#    [342, 47894837, 47509722],
#    [343, 48263983, 47894837],
#    [344, 48266370, 48263983]],
#   'epochVoteAccount': True,
#   'lastVote': 148610905,
#   'nodePubkey': 'DeJWX8UZRM7RAE1vDRNL3vvQX3UMorMYXEUtrMBQ97Kp',
#   'rootSlot': 148610866,
#   'votePubkey': '9RESCLjQJ8yNogof4SdyWPUkzixNveEADFvrxr6dYCwL'},
#  {'activatedStake': 1516020169957,
#   'commission': 0,
#   'epochCredits': [[340, 12037569, 11673738],
#    [341, 12386140, 12037569],
#    [342, 12768850, 12386140],
#    [343, 13135655, 12768850],
#    [344, 13138023, 13135655]],
#   'epochVoteAccount': True,
#   'lastVote': 148610905,
#   'nodePubkey': 'CoG8d9Fp2TFJRkAmrPMiPsGhQWHzdTTVoegEp9svRgmJ',
#   'rootSlot': 148610865,
#   'votePubkey': '2NxEEbhqqj1Qptq5LXLbDTP5tLa9f7PqkU8zNgxbGU9P'},
#  {'activatedStake': 1214393708795134,
#   'commission': 100,
#   'epochCredits': [[340, 58002562, 57635195],
#    [341, 58344908, 58002562],
#    [342, 58729427, 58344908],
#    [343, 59100376, 58729427],
#    [344, 59102734, 59100376]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '3ab2iWqdSjyaVVrPTJXRR9e9orqK4AMCrnc5EMEHGu2e',
#   'rootSlot': 148610867,
# ...
#   'rootSlot': 148610867,
#   'votePubkey': 'DSRnpPkLWLA5V2TZo3AJwe2eGfkZ4ZaCwRf2v7e4aXg7'},
#  {'activatedStake': 72885555866995,
#   'commission': 10,
#   'epochCredits': [[340, 37502970, 37135288],
#    [341, 37856749, 37502970],
#    [342, 38242127, 37856749],
#    [343, 38613963, 38242127],
#    [344, 38616350, 38613963]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': 'BZbwrachjwGiPxiynLCgknkaUYAVJFUsqYLB8wXTrKd4',
#   'rootSlot': 148610863,
#   'votePubkey': 'EmXn9UUNxkXZyKZJHFoVmBK9ETFrfTtFmmEY4U4RfbAH'},
#  {'activatedStake': 73444151960117,
#   'commission': 10,
#   'epochCredits': [[340, 76859359, 76495241],
#    [341, 77212850, 76859359],
#    [342, 77597876, 77212850],
#    [343, 77967874, 77597876],
#    [344, 77970246, 77967874]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'Hp9NMFfFhDQJCkgUHLajoWqTjm1xxdvQEyUnoYn1GWFX',
#   'rootSlot': 148610869,
#   'votePubkey': 'FM9TSfBK3Xcdj2KY91hUZveSbiTDCBbaYkDbL1ksdwvn'},
#  {'activatedStake': 1225076383367598,
#   'commission': 4,
#   'epochCredits': [[340, 17120387, 16757915],
#    [341, 17469628, 17120387],
#    [342, 17852602, 17469628],
#    [343, 18219989, 17852602],
#    [344, 18222319, 18219989]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '2dfgsiSaZ51QYPsECMYMG247PXxyKdwkV9wTHoQb8YEC',
#   'rootSlot': 148610866,
#   'votePubkey': 'NDf9Pv6TAxTDPR6ud3djsd2Ux1WS2m2YfTw4qEmSnQH'},
#  {'activatedStake': 72005555365765,
#   'commission': 10,
#   'epochCredits': [[340, 34156034, 33793990],
#    [341, 34508763, 34156034],
#    [342, 34893874, 34508763],
#    [343, 35261266, 34893874],
#    [344, 35263637, 35261266]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'auzyWJi8E1NVBEUYZezBc8bS1GZYTVnhpdc53zH7PPH',
#   'rootSlot': 148610867,
#   'votePubkey': 'auzvUyNhfsyUP658t2C6zgZ2vxQggzS8PEEGfwVzCBP'},
#  {'activatedStake': 73651058665722,
#   'commission': 10,
#   'epochCredits': [[340, 64380076, 64015754],
#    [341, 64729097, 64380076],
#    [342, 65112389, 64729097],
#    [343, 65476803, 65112389],
#    [344, 65479146, 65476803]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '6npqjzgFPuL7dKdaUsgLwKokWLDe3wFyHeDaVT7Pro3d',
#   'rootSlot': 148610866,
#   'votePubkey': 'AU4yDLbrnLzcjk2pnxvXwNeKJsj9CiUDRXWQbeSbk6Y9'},
#  {'activatedStake': 81671322674882,
#   'commission': 10,
#   'epochCredits': [[340, 76407053, 76039725],
#    [341, 76760751, 76407053],
#    [342, 77145612, 76760751],
#    [343, 77512507, 77145612],
#    [344, 77514885, 77512507]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': '8X4SDANraPWJYCDB1ZYCucraB1TKki7vTFcJMiSrspTY',
#   'rootSlot': 148610866,
#   'votePubkey': 'F7oKL1VEeL5YGNwyFZABpiBiT6i6N11HYJex7jGKSpeZ'},
#  {'activatedStake': 167198240958,
#   'commission': 10,
#   'epochCredits': [[340, 6810649, 6443398],
#    [341, 7138632, 6810649],
#    [342, 7523473, 7138632],
#    [343, 7895142, 7523473],
#    [344, 7897514, 7895142]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '6Yj58NgdE1AAWNnyJVMWUxfWeuf1LjsnfQF8pjrhjLYq',
#   'rootSlot': 148610867,
#   'votePubkey': 'CGouaT8LQhNe3SJiAoNdg6RrcyKCCvgSq4GBvA9YqKiu'},
#  {'activatedStake': 78933865423184,
#   'commission': 10,
#   'epochCredits': [[340, 118879630, 118512182],
#    [341, 119233242, 118879630],
#    [342, 119618062, 119233242],
#    [343, 119987635, 119618062],
#    [344, 119990007, 119987635]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': 'Fudp7uPDYNYQRxoq1Q4JiwJnzyxhVz37bGqRki3PBzS',
#   'rootSlot': 148610866,
#   'votePubkey': '4QhNoG3PN1FXXFhAEA2QWdor6xjXvM9pjq6MXAUV8Zg2'},
#  {'activatedStake': 68033772694889,
#   'commission': 10,
#   'epochCredits': [[340, 2498952, 2131379],
#    [341, 2852705, 2498952],
#    [342, 3237293, 2852705],
#    [343, 3608805, 3237293],
#    [344, 3611204, 3608805]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'GBGW4K7R79Gaaeot3m6A7CgT7kWzDp2TSs8highVExAK',
#   'rootSlot': 148610867,
#   'votePubkey': '5pqis66S1mSpDGmg7T5wLFqPnb524T5gzgxu2iqF1kWN'},
#  {'activatedStake': 80749117194402,
#   'commission': 10,
#   'epochCredits': [[340, 73329389, 72962157],
#    [341, 73642917, 73329389],
#    [342, 74028313, 73642917],
#    [343, 74395650, 74028313],
#    [344, 74398012, 74395650]],
#   'epochVoteAccount': True,
#   'lastVote': 148610905,
#   'nodePubkey': '4ZToBgveZ5m8NySrDyPA2fiGVRVBioaoMXD31KGidm65',
#   'rootSlot': 148610865,
#   'votePubkey': 'Dh4K8fNV6pRFZtbzQnP5a5HmyBPb2kmxvWiYmc5fJMvj'},
#  {'activatedStake': 71436679671648,
#   'commission': 10,
#   'epochCredits': [[340, 12194590, 11829992],
#    [341, 12548011, 12194590],
#    [342, 12933529, 12548011],
#    [343, 13302218, 12933529],
#    [344, 13304579, 13302218]],
#   'epochVoteAccount': True,
#   'lastVote': 148610905,
#   'nodePubkey': 'LmYB43ohYCTaygofDPF65XF8QcpkUdt6k3ydY2XU2GU',
#   'rootSlot': 148610865,
#   'votePubkey': 'CqDkE6NwoHNyRdU3x4h52pKrf3iD4RyTszwhNYyRyXKm'},
#  {'activatedStake': 73570458509865,
#   'commission': 10,
#   'epochCredits': [[340, 38056252, 37692857],
#    [341, 38411018, 38056252],
#    [342, 38796100, 38411018],
#    [343, 39165275, 38796100],
#    [344, 39167634, 39165275]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': 'HGxuzkeuu9CnsysJWXzDM54SVgBhrVq53qn8GivYgsss',
#   'rootSlot': 148610866,
#   'votePubkey': '7nGrgspv4vpyadsRGmn2MjFyLweVTTNJotVYaPFEHsnq'},
#  {'activatedStake': 86989960101506,
#   'commission': 10,
#   'epochCredits': [[340, 30060878, 29692352],
#    [341, 30414690, 30060878],
#    [342, 30799572, 30414690],
#    [343, 31166498, 30799572],
#    [344, 31168872, 31166498]],
#   'epochVoteAccount': True,
#   'lastVote': 148610905,
#   'nodePubkey': '6M6MmdSwyW7UjXb8MzqFRAKQ1ksSXyPTMsXY1DajdNi6',
#   'rootSlot': 148610865,
#   'votePubkey': 'HSrVYheVzxb298uP83jFpS3ZHAEk8jJfJ25cbnnZ2gBp'},
#  {'activatedStake': 71440275511612,
#   'commission': 10,
#   'epochCredits': [[340, 4618799, 4250838],
#    [341, 4969438, 4618799],
#    [342, 5354213, 4969438],
#    [343, 5724204, 5354213],
#    [344, 5726596, 5724204]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '39Nkfh7qezhNFp7yPxS57KBgWaUtABG5tJyh21HbtZPL',
#   'rootSlot': 148610867,
#   'votePubkey': 'G3S7AjkVSEX47HzEYfKasjMX1dRueJusKsgg8ceTmtfT'},
#  {'activatedStake': 73428554030480,
#   'commission': 10,
#   'epochCredits': [[340, 64140879, 63776357],
#    [341, 64491619, 64140879],
#    [342, 64871681, 64491619],
#    [343, 65240523, 64871681],
#    [344, 65242910, 65240523]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': 'SoLiDDAQBEK1LK8apZcZqY7FunqeqDY6nYXMabQZvPB',
#   'rootSlot': 148610866,
#   'votePubkey': 'SoLiDFg9qMi7tFEo4tiLxEVE7mteRyGZkBHJn2YYyjP'},
#  {'activatedStake': 71757273113047,
#   'commission': 10,
#   'epochCredits': [[340, 12571899, 12205741],
#    [341, 12924868, 12571899],
#    [342, 13309957, 12924868],
#    [343, 13679571, 13309957],
#    [344, 13681946, 13679571]],
#   'epochVoteAccount': True,
#   'lastVote': 148610905,
#   'nodePubkey': 'E9XZMQKPoWAFw9Q1YckTEN5BF2N1cRaFFkUmkS4u7EMG',
#   'rootSlot': 148610866,
#   'votePubkey': 'EwyKH3mvN2EBSCFmWZmyahRUQbR4WgYqbhzmAg2LYpFL'},
#  {'activatedStake': 838381326319306,
#   'commission': 100,
#   'epochCredits': [[340, 57528946, 57161568],
#    [341, 57881028, 57528946],
#    [342, 58266142, 57881028],
#    [343, 58637247, 58266142],
#    [344, 58639610, 58637247]],
#   'epochVoteAccount': True,
#   'lastVote': 148610895,
#   'nodePubkey': 'FfM4oeeszBdHJys9yPFV6hkcZB3ea5GuMYj81aVLURVK',
#   'rootSlot': 148610863,
#   'votePubkey': 'HUAnFVknuEfzsybhCqKsLZoST3UCxppxfVKJ4mT9u4mL'},
#  {'activatedStake': 822378713151360,
#   'commission': 100,
#   'epochCredits': [[340, 47303740, 46940031],
#    [341, 47657249, 47303740],
#    [342, 48041938, 47657249],
#    [343, 48412608, 48041938],
#    [344, 48414990, 48412608]],
#   'epochVoteAccount': True,
#   'lastVote': 148610895,
#   'nodePubkey': '5dgjNR6Ru9VbmhJBSeWmQm17VSEYcstgQini429ePEyG',
#   'rootSlot': 148610863,
#   'votePubkey': 'G2pFiYziSkjGTvfNGnHhFCG5TMgZHQQLfi3VdxuLfL2C'},
#  {'activatedStake': 73018519435967,
#   'commission': 10,
#   'epochCredits': [[340, 36493048, 36125500],
#    [341, 36845173, 36493048],
#    [342, 37230560, 36845173],
#    [343, 37596054, 37230560],
#    [344, 37598414, 37596054]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': '3crXzLp31ZBmBaVtqqsyguv1QwrmTQeH544hmSmuX6UH',
#   'rootSlot': 148610866,
#   'votePubkey': 'HsUhGC6yKwr8kLC5gdqVLrDfKsGCd2ZAXiabP1WojuzA'},
#  {'activatedStake': 73015950678514,
#   'commission': 10,
#   'epochCredits': [[340, 29191797, 28827757],
#    [341, 29542072, 29191797],
#    [342, 29924370, 29542072],
#    [343, 30289610, 29924370],
#    [344, 30291972, 30289610]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': '2b4thJkc3dAYM595fRCzCAQkzdg6UM5cAmBqrPRUDJ7F',
#   'rootSlot': 148610866,
#   'votePubkey': 'GAerry2FZncXgLJXohjgGmC3W4JKLDFxwhGz4beTgDeP'},
#  {'activatedStake': 73019854687079,
#   'commission': 10,
#   'epochCredits': [[340, 36227443, 35861561],
#    [341, 36578780, 36227443],
#    [342, 36963619, 36578780],
#    [343, 37330439, 36963619],
#    [344, 37332813, 37330439]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'AVWUjHQW5Eocbq4dPsFsMLc1WKHvXHVEeiQYv6pVvMkW',
#   'rootSlot': 148610863,
#   'votePubkey': 'Foo9xhhkDqP24egwYNaWcTh2ZdAAV79UJSuemrsMisLt'},
#  {'activatedStake': 195928236845594,
#   'commission': 100,
#   'epochCredits': [[340, 43797876, 43430712],
#    [341, 44150247, 43797876],
#    [342, 44531640, 44150247],
#    [343, 44899492, 44531640],
#    [344, 44901869, 44899492]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '4BCjQ8tfHdBvjLsQzvaTmSPasTKaM4L8NVKD8tKd79Xa',
#   'rootSlot': 148610869,
#   'votePubkey': 'FERNT7FPaRgz18Zc5buW3vKg4YKwvadKVvUDfy7xYNi'},
#  {'activatedStake': 89117683724803,
#   'commission': 10,
#   'epochCredits': [[340, 75553179, 75187002],
#    [341, 75902615, 75553179],
#    [342, 76285507, 75902615],
#    [343, 76652374, 76285507],
#    [344, 76654753, 76652374]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '2Ce1dmtdnvgDwD1MiZjP9wwGup6j8H7uXGuGMa9uZo5v',
#   'rootSlot': 148610863,
#   'votePubkey': 'GTeoHau1SpLhoiDGJdQpGd7AS3gyaFLgGVG2EHQRHoWp'},
#  {'activatedStake': 8414903358493,
#   'commission': 10,
#   'epochCredits': [[340, 26480582, 26168250],
#    [341, 26792559, 26480582],
#    [342, 27135159, 26792559],
#    [343, 27501990, 27135159],
#    [344, 27504383, 27501990]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '2DWwKJ1mUyRWbWcTuLM3K8SMm4oxvYpYC5QYhQntZywA',
#   'rootSlot': 148610867,
#   'votePubkey': 'He7U68QpevU4VT9K5xxQL9sxTBAQ5R7obZeav19XRTQ2'},
#  {'activatedStake': 73441377057642,
#   'commission': 10,
#   'epochCredits': [[340, 48036182, 47668725],
#    [341, 48390302, 48036182],
#    [342, 48775333, 48390302],
#    [343, 49133569, 48775333],
#    [344, 49135927, 49133569]],
#   'epochVoteAccount': True,
#   'lastVote': 148610905,
#   'nodePubkey': 'CQKC4kB27Gm9i9u54USbUrQ4WVrBSdWT9srMz8p5x7qt',
#   'rootSlot': 148610865,
#   'votePubkey': 'CHUF69YeA3gZv484izYuhKk1EjaJYjv1pNoJJ6QeFDQc'},
#  {'activatedStake': 72061925519885,
#   'commission': 10,
#   'epochCredits': [[340, 17719687, 17352711],
#    [341, 18072257, 17719687],
#    [342, 18457163, 18072257],
#    [343, 18828809, 18457163],
#    [344, 18831157, 18828809]],
#   'epochVoteAccount': True,
#   'lastVote': 148610895,
#   'nodePubkey': 'uMSgHLmbksQav7zjReRUBYUa5pxMTpzP5YUeYLJbdor',
#   'rootSlot': 148610863,
#   'votePubkey': '2qJHXAzWHdnYJr2eosEqhoddephQChSCESdnJCPkd9tA'},
#  {'activatedStake': 82209402318672,
#   'commission': 10,
#   'epochCredits': [[340, 76528860, 76161685],
#    [341, 76882236, 76528860],
#    [342, 77267308, 76882236],
#    [343, 77636047, 77267308],
#    [344, 77638412, 77636047]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '7R3t8NAU7NDAd64KLz62tj1TaFZLmSyVSMRJX8VT8Agp',
#   'rootSlot': 148610867,
#   'votePubkey': 'GQWkfg91PsW6A7vPVCHN5SM5umBERMKjdyqzhB1nqQTB'},
#  {'activatedStake': 107735574093944,
#   'commission': 10,
#   'epochCredits': [[340, 37734899, 37367344],
#    [341, 38087893, 37734899],
#    [342, 38472646, 38087893],
#    [343, 38844421, 38472646],
#    [344, 38846647, 38844421]],
#   'epochVoteAccount': True,
#   'lastVote': 148610895,
#   'nodePubkey': 'SerGoB2ZUyi9A1uBFTRpGxxaaMtrFwbwBpRytHefSWZ',
#   'rootSlot': 148610863,
#   'votePubkey': 'BWkvytz3MAiLkUbMuYK5yV1VYThbBYYQYG3gdef8NLw5'},
#  {'activatedStake': 72908189982683,
#   'commission': 10,
#   'epochCredits': [[340, 37713669, 37346102],
#    [341, 38066804, 37713669],
#    [342, 38451528, 38066804],
#    [343, 38820286, 38451528],
#    [344, 38822679, 38820286]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'CGQe9dUhj58hb83zotLUsTTinGVBQkpGaGyyTtE34jo7',
#   'rootSlot': 148610867,
#   'votePubkey': '83V2g2N2gAkt4oWAkXTsCmcSaALtTcoEHtokzDwsEi97'},
#  {'activatedStake': 93529017726870,
#   'commission': 10,
#   'epochCredits': [[340, 76834065, 76466989],
#    [341, 77187634, 76834065],
#    [342, 77572152, 77187634],
#    [343, 77940168, 77572152],
#    [344, 77942557, 77940168]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'Agzs33CozCnr3eFvyHcYkb46nUZq4dL9SFMV9CNAxfGR',
#   'rootSlot': 148610867,
#   'votePubkey': 'BL1CZTB8nZShHexKt2jWmHJe4jShRSbRn71BGhmYSFc2'},
#  {'activatedStake': 73571453167578,
#   'commission': 10,
#   'epochCredits': [[340, 77007362, 76642432],
#    [341, 77358868, 77007362],
#    [342, 77741884, 77358868],
#    [343, 78110283, 77741884],
#    [344, 78112641, 78110283]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '9JZXYs5TisLa6gra2PDuNibbi2979AZuXNY9zSVGz4UA',
#   'rootSlot': 148610869,
#   'votePubkey': 'BS6tkCiU9yi4GE8E1kvjQaAByLynjRoJ4j8qd6szdwdz'},
#  {'activatedStake': 73573226356572,
#   'commission': 10,
#   'epochCredits': [[340, 49825756, 49461844],
#    [341, 50176154, 49825756],
#    [342, 50558797, 50176154],
#    [343, 50925817, 50558797],
#    [344, 50928209, 50925817]],
#   'epochVoteAccount': True,
#   'lastVote': 148610905,
#   'nodePubkey': '5nk1nNiwGKC1hmCLUoAFL2izBo6aKYnx6Kpvq2XKsMDi',
#   'rootSlot': 148610866,
#   'votePubkey': 'Gj63nResvnBrKLw4GyyfWFpTudwQWDe9bExkE9Z1LvB1'},
#  {'activatedStake': 72385546457824,
#   'commission': 10,
#   'epochCredits': [[340, 23768940, 23405060],
#    [341, 24122528, 23768940],
#    [342, 24506629, 24122528],
#    [343, 24874623, 24506629],
#    [344, 24876982, 24874623]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'C5kwh145KTwPjFyYBKVgjmMFpaVYYeGvsqhN7Ao7a8Np',
#   'rootSlot': 148610867,
#   'votePubkey': '2tiNTQ8a7QLTCivwMu1At5GoqoJRPvMpwmrLKdSdmNg6'},
#  {'activatedStake': 72996348504653,
#   'commission': 10,
#   'epochCredits': [[340, 62859294, 62492639],
#    [341, 63212259, 62859294],
#    [342, 63597354, 63212259],
#    [343, 63965225, 63597354],
#    [344, 63967612, 63965225]],
#   'epochVoteAccount': True,
#   'lastVote': 148610906,
#   'nodePubkey': 'CgX9oSHcpXjKKxUpLbrgNKWrk3ff4cQidfsf96AkMBke',
#   'rootSlot': 148610866,
#   'votePubkey': '5RbNzJrGrfoSgoDCMvx3n8jLAVzTjAjy9dfKFUR3enAy'},
#  {'activatedStake': 1016729398670419,
#   'commission': 0,
#   'epochCredits': [[340, 37168899, 36786860],
#    [341, 37540279, 37168899],
#    [342, 37935469, 37540279],
#    [343, 38320818, 37935469],
#    [344, 38323284, 38320818]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'Frog1Fks1AVN8ywFH3HTFeYojq6LQqoEPzgQFx2Kz5Ch',
#   'rootSlot': 148610869,
#   'votePubkey': 'Pond1QyT1sQtiru3fi9G5LGaLRGeUpJKR1a2gdbq2u4'},
#  {'activatedStake': 72074773074886,
#   'commission': 10,
#   'epochCredits': [[340, 24009894, 23642979],
#    [341, 24356735, 24009894],
#    [342, 24740484, 24356735],
#    [343, 25109947, 24740484],
#    [344, 25112297, 25109947]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': '5fKPZSiab6jib2cd4cvPyody5FEXBA8b1wez2CTx1tz1',
#   'rootSlot': 148610863,
#   'votePubkey': 'AxroSy8ubkN2pk8zbbp4Xw7fTytKdhUr5gfM6gnP3wqj'},
#  {'activatedStake': 72382709037263,
#   'commission': 10,
#   'epochCredits': [[340, 4299099, 3931549],
#    [341, 4652185, 4299099],
#    [342, 5037039, 4652185],
#    [343, 5397992, 5037039],
#    [344, 5400375, 5397992]],
#   'epochVoteAccount': True,
#   'lastVote': 148610907,
#   'nodePubkey': 'C17WLnQTPjqXgmnpu2F1WfbeXdSbzufvnMHuS6XHjsAZ',
#   'rootSlot': 148610867,
#   'votePubkey': '3zxkHtntSzfW2rukRFqhN9SDPzqicvF6WwN6yDwdSvxQ'},
#  ...]

# %%
clusterNodeResults = parseResponse(clusterNodeResponse)

# %%
clusterNodeDF = pd.DataFrame.from_dict(clusterNodeResults)
clusterNodeDF
# Out:
#         featureSet                gossip  \
# 0     4.830972e+08   93.187.216.181:8001
# 1     2.324891e+09     141.95.35.64:8001
# 2     2.324891e+09  142.132.128.140:8001
# 3     2.324891e+09    65.108.70.123:8001
# 4     2.324891e+09   104.243.41.140:8000
# ...            ...                   ...
# 3463  3.458834e+09   35.220.222.142:8000
# 3464  1.070292e+09   182.70.113.108:8001
# 3465  2.324891e+09    209.145.53.48:8001
# 3466  4.192065e+09    3.140.239.51:11000
# 3467  2.166664e+07     145.40.81.33:8001
#
#                                             pubkey                  rpc  \
# 0     CrTdNk65pAcBzf5krCVHW1KTKSxPAdyQPWe2gcKgiqDz                 None
# 1     C219S526JWRzpPUm3FfAzobwZMDuo3DM63phtJpqAz75                 None
# 2     E1SFkvPjU31xWMcvgnX6vhGvfRvb1zXvHFkqmQNEGZKK                 None
# 3     2FMWJN52AeqnoTECeicyk724fJbMZLXVyMopBWThyZ1U                 None
# 4     84Za5eXvehQLZR6Xqhe9WT6tTcCHTVjw3XU7GCbBRNfW  104.243.41.140:8899
# ...                                            ...                  ...
# 3463  7NUdbCTUQLXpPbUZdPWQPexXTfhzPgd4KutWGpSBgB5r                 None
# 3464  7z8LtWZaoo6pFYHPA6PfbZUvzr3ZdsjPtogeuCxm3UCm                 None
# 3465  6v1zV6dJzJ3TmUcjnn4K3CpaFxWL5geWjC1XQ9kR3SLf                 None
# 3466  9j1VRA8ZgKa8tHbRRXchPCqJa2muqfMa1CqydTsZfELH                 None
# 3467   mce3QKzeRNwk3TC6XfHTy5hdRT6u5UKm4rKQbNKkFhF      145.40.81.33:80
#
#       shredVersion                   tpu  version
# 0            51382   93.187.216.181:8004  1.10.35
# 1            51382     141.95.35.64:8004  1.10.38
# 2            51382  142.132.128.140:8003  1.10.38
# 3            51382    65.108.70.123:8004  1.10.38
# 4            51382   104.243.41.140:8003  1.10.38
# ...            ...                   ...      ...
# 3463         51382                  None    1.6.8
# 3464         51382                  None   1.9.18
# 3465         51382    209.145.53.48:8004  1.10.38
# 3466         51382                  None  1.10.31
# 3467         51382     145.40.81.33:8004   1.12.0
#
# [3468 rows x 7 columns]

# %%
voteAccountDF = pd.DataFrame.from_dict(voteAccountsResults['current'])
voteAccountDF
# Out:
#         activatedStake  commission  \
# 0       73446440809731          10
# 1       71439993594343          10
# 2      202162131716288         100
# 3       72763333999262          10
# 4     2591235614994379         100
# ...                ...         ...
# 1896   166458467306044           9
# 1897    71754425884936          10
# 1898    65187746807499          10
# 1899    87478553223929          10
# 1900  3569888709977182         100
#
#                                            epochCredits  epochVoteAccount  \
# 0     [[340, 43315131, 42947787], [341, 43668868, 43...              True
# 1     [[340, 9389689, 9021867], [341, 9743124, 93896...              True
# 2     [[340, 42961309, 42593818], [341, 43314851, 42...              True
# 3     [[340, 28322393, 27955157], [341, 28652627, 28...              True
# 4     [[340, 61509702, 61142220], [341, 61860579, 61...              True
# ...                                                 ...               ...
# 1896  [[340, 18093396, 17738935], [341, 18446721, 18...              True
# 1897  [[340, 10509711, 10174616], [341, 10864108, 10...              True
# 1898  [[340, 22208106, 21843929], [341, 22557531, 22...              True
# 1899  [[340, 43645807, 43281387], [341, 43996293, 43...              True
# 1900  [[340, 61223175, 60856219], [341, 61574644, 61...              True
#
#        lastVote                                    nodePubkey   rootSlot  \
# 0     148610907  EJQfuuRgKngEE199LYyqAdNqmE3Ms5EMwLa7F7a4PuWA  148610867
# 1     148610906  CFeXt8sBqgagHSkbsPfw9MpbffmxwBVKp6Jdjc8yACeQ  148610866
# 2     148610895  8L3JhKEZWiCyvVuEAzXeDjkziptj1XZsFFZReD5s3DZY  148610863
# 3     148610907  3mPiMjCvfawQD753b3jw4YPWwywTg6bBrRwmj5gmXWcD  148610866
# 4     148610906  EaRH6eMWnXKXhw1tqve6eUXnsoWYUFKeSbXUyBEqyPYJ  148610866
# ...         ...                                           ...        ...
# 1896  148610906  C37s7TGwqF6Yk1XMxBAWzEt5J2dAUP5NfyjXoZuKFi2f  148610866
# 1897  148610907  HNWjp9mLTP5jAiLUYgbLrK8d33VSguhSYHSNAjf8E2H1  148610863
# 1898  148610907  51ZywJopPJosXqbXahgYqz5ALPpi8v7PNrkzaKTLBRac  148610869
# 1899  148610907  F5NHy2fuNfESepcuefCQ8peba38c5Z7fsZb6dQZHHWi7  148610867
# 1900  148610907   hz4sZFVC1MccN3WaSZ8YjHcZLewLw2JL7t1RfaRa4Pe  148610867
#
#                                         votePubkey
# 0     59ygup4yDt6s7BEtACkbrUQnutK6883ThPx6ZS7QrFb4
# 1     C33g1CBgcc47XFcrYksA3CEkBKaitKuhs9yD7LLtW98K
# 2     3JwUXwdCHLazV1oaUY8Yg87eWS8sE7qTpbJ2BZRQBjru
# 3     4ebYDbb3D9mjgAYc813oJ8aQtSE3u6QRu3rBHxiJ72Pk
# 4     31J7VodSmMhebVNmR3BVsBkv4rrpbEmGKQm1yKscsZH5
# ...                                            ...
# 1896  JE4BXFW3iq3XWr8MfiCnsc5eTFCGfux2JKCWm33wNDXc
# 1897  A7uE85Qd4Wbw4TdF9sqbqpbPSKYpes6Q8Jc3DZeYfuMm
# 1898  7ijG5keU7kjADTaXxoanvfy6pbWxWq2aQ5p17VdK9fDQ
# 1899  68yZX4mnV8vgefSNTWcaEHYUQt9XTzW8p5tt5r4PWseh
# 1900  5KAXjaRTfyuUqd94y7rj1HmTbmdjt3266j9c44RrPRuw
#
# [1901 rows x 8 columns]

# %%
#voteAccountDF_join_clusterNodeDF = voteAccountDF.set_index('nodePubkey').join(clusterNodeDF.set_index('pubkey'))
clusterNodeDF.rename(columns = {'pubkey': 'nodePubkey'}, inplace = True)
voteAccountDF_join_clusterNodeDF = pd.merge(voteAccountDF, clusterNodeDF, on = "nodePubkey")
voteAccountDF_join_clusterNodeDF.head()
# Out:
#      activatedStake  commission  \
# 0    73446440809731          10
# 1    71439993594343          10
# 2   202162131716288         100
# 3    72763333999262          10
# 4  2591235614994379         100
#
#                                         epochCredits  epochVoteAccount  \
# 0  [[340, 43315131, 42947787], [341, 43668868, 43...              True
# 1  [[340, 9389689, 9021867], [341, 9743124, 93896...              True
# 2  [[340, 42961309, 42593818], [341, 43314851, 42...              True
# 3  [[340, 28322393, 27955157], [341, 28652627, 28...              True
# 4  [[340, 61509702, 61142220], [341, 61860579, 61...              True
#
#     lastVote                                    nodePubkey   rootSlot  \
# 0  148610907  EJQfuuRgKngEE199LYyqAdNqmE3Ms5EMwLa7F7a4PuWA  148610867
# 1  148610906  CFeXt8sBqgagHSkbsPfw9MpbffmxwBVKp6Jdjc8yACeQ  148610866
# 2  148610895  8L3JhKEZWiCyvVuEAzXeDjkziptj1XZsFFZReD5s3DZY  148610863
# 3  148610907  3mPiMjCvfawQD753b3jw4YPWwywTg6bBrRwmj5gmXWcD  148610866
# 4  148610906  EaRH6eMWnXKXhw1tqve6eUXnsoWYUFKeSbXUyBEqyPYJ  148610866
#
#                                      votePubkey    featureSet  \
# 0  59ygup4yDt6s7BEtACkbrUQnutK6883ThPx6ZS7QrFb4  2.324891e+09
# 1  C33g1CBgcc47XFcrYksA3CEkBKaitKuhs9yD7LLtW98K  2.324891e+09
# 2  3JwUXwdCHLazV1oaUY8Yg87eWS8sE7qTpbJ2BZRQBjru  4.830972e+08
# 3  4ebYDbb3D9mjgAYc813oJ8aQtSE3u6QRu3rBHxiJ72Pk  4.830972e+08
# 4  31J7VodSmMhebVNmR3BVsBkv4rrpbEmGKQm1yKscsZH5  2.324891e+09
#
#                  gossip                  rpc  shredVersion  \
# 0   104.243.37.172:8000  104.243.37.172:8899         51382
# 1   65.108.107.101:8000  65.108.107.101:8899         51382
# 2  108.171.215.138:8001                 None         51382
# 3   141.94.134.223:8001                 None         51382
# 4   145.40.113.237:8001                 None         51382
#
#                     tpu  version
# 0   104.243.37.172:8003  1.10.38
# 1   65.108.107.101:8003  1.10.38
# 2  108.171.215.138:8004  1.10.35
# 3   141.94.134.223:8004  1.10.35
# 4   145.40.113.237:8003  1.10.38

# %%
voteAccountDF_join_clusterNodeDF['pubkey_diff'] = np.where((voteAccountDF_join_clusterNodeDF['nodePubkey'] == voteAccountDF_join_clusterNodeDF['votePubkey'] ), True, False)
same_key_mask = voteAccountDF_join_clusterNodeDF['pubkey_diff'].values == True

same_key_df = voteAccountDF_join_clusterNodeDF[same_key_mask]
same_key_df
# Out:
# Empty DataFrame
# Columns: [activatedStake, commission, epochCredits, epochVoteAccount, lastVote, nodePubkey, rootSlot, votePubkey, featureSet, gossip, rpc, shredVersion, tpu, version, pubkey_diff]
# Index: []

# %%
rpc_address_mask = voteAccountDF_join_clusterNodeDF['rpc'].values != None
rpc_address_df = voteAccountDF_join_clusterNodeDF[rpc_address_mask]
rpc_address_df
# Out:
#        activatedStake  commission  \
# 0      73446440809731          10
# 1      71439993594343          10
# 9      70810072807707          10
# 14     72901044625881          10
# 17     73190355836438          10
# ...               ...         ...
# 1874   64249955463501           5
# 1875   73568449382423          10
# 1886   73444091707027          10
# 1895   54199847735369          10
# 1896  166458467306044           9
#
#                                            epochCredits  epochVoteAccount  \
# 0     [[340, 43315131, 42947787], [341, 43668868, 43...              True
# 1     [[340, 9389689, 9021867], [341, 9743124, 93896...              True
# 9     [[340, 4833354, 4468140], [341, 5185747, 48333...              True
# 14    [[340, 28419202, 28054922], [341, 28768312, 28...              True
# 17    [[340, 39254719, 38887911], [341, 39604815, 39...              True
# ...                                                 ...               ...
# 1874  [[340, 30654631, 30289744], [341, 31004168, 30...              True
# 1875  [[340, 64250197, 63886120], [341, 64599616, 64...              True
# 1886  [[340, 50117066, 49753474], [341, 50466107, 50...              True
# 1895  [[340, 28406218, 28038592], [341, 28759741, 28...              True
# 1896  [[340, 18093396, 17738935], [341, 18446721, 18...              True
#
#        lastVote                                    nodePubkey   rootSlot  \
# 0     148610907  EJQfuuRgKngEE199LYyqAdNqmE3Ms5EMwLa7F7a4PuWA  148610867
# 1     148610906  CFeXt8sBqgagHSkbsPfw9MpbffmxwBVKp6Jdjc8yACeQ  148610866
# 9     148610907  DDMM7C218XeNSDqw8us9szA1Ss92Ag7EJE9rGEz8Qtdo  148610867
# 14    148610907  B3uXszjkQfWAhs5eBSPvoapddJGuBN32ncNFi7CMjmYD  148610863
# 17    148610907  8fp2i8jhVcspsXUcHMQAnfQknT9nmuxFASdv6kV2FkwU  148610869
# ...         ...                                           ...        ...
# 1874  148610907  CquA9q57TYVr9uvXvk6aqAG5GGKk3mUL9C8ALyAsUeWg  148610863
# 1875  148610895  6kfL3zErU3z9iofwdg6iM6UJDFZaVJNguAwy8SiN82db  148610863
# 1886  148610907  2n2xqWM9Z18LqxfJzkNrMMFWiDUFYA2k6WSgSnf6EnJs  148610867
# 1895  148610907  F97xU2xEfFN3d3J33dd2hDJb7WASDqLGRUqznXS2i2ig  148610863
# 1896  148610906  C37s7TGwqF6Yk1XMxBAWzEt5J2dAUP5NfyjXoZuKFi2f  148610866
#
#                                         votePubkey    featureSet  \
# 0     59ygup4yDt6s7BEtACkbrUQnutK6883ThPx6ZS7QrFb4  2.324891e+09
# 1     C33g1CBgcc47XFcrYksA3CEkBKaitKuhs9yD7LLtW98K  2.324891e+09
# 9     52HBJgFBWwMSk6maAqMshgc1iniQKrRiTgXsQCCT66XA  2.324891e+09
# 14    EtGWDbP7342Mo2PnG6MYUP1rL8v69ycn1FRnRTB1BLU3  4.830972e+08
# 17    Cc7UtVq4G25VbC3w6Ccs2XL2xikjc926q1sHp8zfddoL  4.830972e+08
# ...                                            ...           ...
# 1874  F1FkySZudpAUwfzcgrGVJTrQKFGg2bxBMJooNhRX1RBB  2.324891e+09
# 1875  FvrZudS8hmEfM4PUF2xgVxzgyDqRJdT9byHmdkzAQWps  2.324891e+09
# 1886  Azz9EmNuhtjoYrhWvidWx1Hfd14SNBsYyzXhA9Tnoca8  2.324891e+09
# 1895  5GKFk6ptwtYTUVXZwofK3tgCJXRiQBfY6yS9w8dgZaSS  2.324891e+09
# 1896  JE4BXFW3iq3XWr8MfiCnsc5eTFCGfux2JKCWm33wNDXc  4.830972e+08
#
#                     gossip                   rpc  shredVersion  \
# 0      104.243.37.172:8000   104.243.37.172:8899         51382
# 1      65.108.107.101:8000   65.108.107.101:8899         51382
# 9      65.108.205.149:8000   65.108.205.149:8899         51382
# 14    142.132.150.150:8000  142.132.150.150:8899         51382
# 17      141.95.204.52:8000    141.95.204.52:8899         51382
# ...                    ...                   ...           ...
# 1874    185.188.42.42:9000    185.188.42.42:8899         51382
# 1875   141.94.171.240:8000   141.94.171.240:8899         51382
# 1886    141.95.205.82:8000    141.95.205.82:8899         51382
# 1895  142.132.128.233:8000  142.132.128.233:8899         51382
# 1896   34.252.210.92:11000    34.252.210.92:8899         51382
#
#                        tpu  version  pubkey_diff
# 0      104.243.37.172:8003  1.10.38        False
# 1      65.108.107.101:8003  1.10.38        False
# 9      65.108.205.149:8003  1.10.38        False
# 14    142.132.150.150:8003  1.10.35        False
# 17      141.95.204.52:8003  1.10.35        False
# ...                    ...      ...          ...
# 1874    185.188.42.42:9003  1.10.38        False
# 1875   141.94.171.240:8003  1.10.38        False
# 1886    141.95.205.82:8003  1.10.38        False
# 1895  142.132.128.233:8003  1.10.38        False
# 1896   34.252.210.92:11003  1.10.35        False
#
# [274 rows x 15 columns]
